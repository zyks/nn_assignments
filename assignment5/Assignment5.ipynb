# %% [markdown]
# # Assignment 5
#
# **Submission deadline: last lab session before or on Tuesday, 09.5.17**
#
# **Points: 9 + 10 bonus points**
#
#
# ## Downloading this notebook
#
# This assignment is an Jupyter notebook. Download it by cloning https://github.com/janchorowski/nn_assignments. Follow the instructions in its README for instructions.
#
# For programming exerciese add your solutions to the notebook. For math exercies please provide us with answers on paper or type them in the notebook (it supports Latex-like equations).
#
# Please do not hesitate to use GitHub’s pull requests to send us corrections!

# %%
# %pylab inline
# Out:
# Vendor:  Continuum Analytics, Inc.
# Package: mkl
# Message: trial mode expires in 22 days
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Modular network implementation
#
# This assignment builds on code from Assignment 4, Problem 7.
# For your convenience, we have copied the code below. Please copy your solution from the old list, or fill in the blanks below to get a working network.
#
# In the following cells, I implement in a modular way a feedforward neural network. Please study the code - many network implementations follow a similar pattern.
#
# Please make sure that the network trains to nearly 100% accuracy on Iris.
#
# ## Task
#
# Your job is to implement SGD training on MNIST with the following elements:
# 1. SGD + momentum
# 2. weight decay
# 3. early stopping
#
# In overall, you should get below **2% testing errors**

# %%
#
# These are taken from https://github.com/mila-udem/blocks
# 

class Constant():
    """Initialize parameters to a constant.
    The constant may be a scalar or a :class:`~numpy.ndarray` of any shape
    that is broadcastable with the requested parameter arrays.
    Parameters
    ----------
    constant : :class:`~numpy.ndarray`
        The initialization value to use. Must be a scalar or an ndarray (or
        compatible object, such as a nested list) that has a shape that is
        broadcastable with any shape requested by `initialize`.
    """
    def __init__(self, constant):
        self._constant = numpy.asarray(constant)

    def generate(self, rng, shape):
        dest = numpy.empty(shape, dtype=np.float32)
        dest[...] = self._constant
        return dest


class IsotropicGaussian():
    """Initialize parameters from an isotropic Gaussian distribution.
    Parameters
    ----------
    std : float, optional
        The standard deviation of the Gaussian distribution. Defaults to 1.
    mean : float, optional
        The mean of the Gaussian distribution. Defaults to 0
    Notes
    -----
    Be careful: the standard deviation goes first and the mean goes
    second!
    """
    def __init__(self, std=1, mean=0):
        self._mean = mean
        self._std = std

    def generate(self, rng, shape):
        m = rng.normal(self._mean, self._std, size=shape)
        return m.astype(np.float32)


class Uniform():
    """Initialize parameters from a uniform distribution.
    Parameters
    ----------
    mean : float, optional
        The mean of the uniform distribution (i.e. the center of mass for
        the density function); Defaults to 0.
    width : float, optional
        One way of specifying the range of the uniform distribution. The
        support will be [mean - width/2, mean + width/2]. **Exactly one**
        of `width` or `std` must be specified.
    std : float, optional
        An alternative method of specifying the range of the uniform
        distribution. Chooses the width of the uniform such that random
        variates will have a desired standard deviation. **Exactly one** of
        `width` or `std` must be specified.
    """
    def __init__(self, mean=0., width=None, std=None):
        if (width is not None) == (std is not None):
            raise ValueError("must specify width or std, "
                             "but not both")
        if std is not None:
            # Variance of a uniform is 1/12 * width^2
            self._width = numpy.sqrt(12) * std
        else:
            self._width = width
        self._mean = mean

    def generate(self, rng, shape):
        w = self._width / 2
        m = rng.uniform(self._mean - w, self._mean + w, size=shape)
        return m.astype(np.float32)

# %%
class Layer(object):
    def __init__(self, rng=None):
        if rng is None:
            rng = numpy.random
        self.rng = rng
    
    @property
    def parameters(self):
        return []
    
    @property
    def parameter_names(self):
        return []
    
    def get_gradients(self, dLdY, fprop_context):
        return []
    

class AffineLayer(Layer):
    def __init__(self, num_in, num_out, weight_init=None, bias_init=None, **kwargs):
        super(AffineLayer, self).__init__(**kwargs)
        if weight_init is None:
            #
            # TODO propose a default initialization scheme.
            # Type a sentence explaining why, and if you use a reference, 
            # cite it here
            #
            weight_init = IsotropicGaussian()
        if bias_init is None:
            bias_init = Constant(0.0)
        
        self.W = weight_init.generate(self.rng, (num_out, num_in))
        self.b = bias_init.generate(self.rng, (num_out, 1))
    
    @property
    def parameters(self):
        return [self.W, self.b]
    
    @property
    def parameter_names(self):
        return ['W','b']
    
    def fprop(self, X):
        #Save X for later reusal
        fprop_context = dict(X=X)
        Y = np.dot(self.W, X) +  self.b
        return Y, fprop_context
    
    def bprop(self, dLdY, fprop_context):
        #
        # TODO: fill in gradient computation
        #
        dLdX = (self.W.T).dot(dLdY)
        return dLdX
    
    def get_gradients(self, dLdY, fprop_context):
        X = fprop_context['X']
        dLdW = np.dot(dLdY, X.T)
        dLdb = dLdY.sum(1, keepdims=True)
        return [dLdW, dLdb]
    
class TanhLayer(Layer):
    def __init__(self, **kwargs):
        super(TanhLayer, self).__init__(**kwargs)
    
    def fprop(self, X):
        Y = np.tanh(X)
        fprop_context = dict(Y=Y)
        return Y, fprop_context
    
    def bprop(self, dLdY, fprop_context):
        Y = fprop_context['Y']
        #
        # Fill in proper gradient computation
        #
        return dLdY * (1 - Y**2)

    
class ReLULayer(Layer):
    def __init__(self, **kwargs):
        super(ReLULayer, self).__init__(**kwargs)
    
    def fprop(self, X):
        Y = np.maximum(X, 0.0)
        fprop_context = dict(Y=Y)
        return Y, fprop_context
    
    def bprop(self, dLdY, fprop_context):
        Y = fprop_context['Y']
        return dLdY * (Y>0)

    
class SoftMaxLayer(Layer):
    def __init__(self, **kwargs):
        super(SoftMaxLayer, self).__init__(**kwargs)
    
    def compute_probabilities(self, X):
        O = X - X.max(axis=0, keepdims=True)
        O = np.exp(O)
        O /= O.sum(axis=0, keepdims=True)
        return O
    
    def fprop_cost(self, X, Y):
        NS = X.shape[1]
        O = self.compute_probabilities(X)
        Cost = -1.0/NS * np.log(O[Y.ravel(), range(NS)]).sum()
        return Cost, O, dict(O=O, X=X, Y=Y)
    
    def bprop_cost(self, fprop_context):
        X = fprop_context['X']
        Y = fprop_context['Y']
        O = fprop_context['O']
        NS = X.shape[1]
        dLdX = O.copy()
        dLdX[Y, range(NS)] -= 1.0
        dLdX /= NS
        return dLdX
    
class FeedForwardNet(object):
    def __init__(self, layers=None):
        if layers is None:
            layers = []
        self.layers = layers
    
    def add(self, layer):
        self.layers.append(layer)
    
    @property
    def parameters(self):
        params = []
        for layer in self.layers:
            params += layer.parameters
        return params
    
    @parameters.setter
    def parameters(self, values):
        for ownP, newP in zip(self.parameters, values):
            ownP[...] = newP
    
    @property
    def parameter_names(self):
        param_names = []
        for layer in self.layers:
            param_names += layer.parameter_names
        return param_names
    
    def fprop(self, X):
        for layer in self.layers[:-1]:
            X, fp_context = layer.fprop(X)
        return self.layers[-1].compute_probabilities(X)
    
    def get_cost_and_gradient(self, X, Y):
        fp_contexts = []
        for layer in self.layers[:-1]:
            X, fp_context = layer.fprop(X)
            fp_contexts.append(fp_context)
        
        L, O, fp_context = self.layers[-1].fprop_cost(X, Y)
        dLdX = self.layers[-1].bprop_cost(fp_context)
        
        dLdP = [] #gradient with respect to parameters
        for i in xrange(len(self.layers)-1):
            layer = self.layers[len(self.layers)-2-i]
            fp_context = fp_contexts[len(self.layers)-2-i]
            dLdP = layer.get_gradients(dLdX, fp_context) + dLdP
            dLdX = layer.bprop(dLdX, fp_context)
        return L, O, dLdP

# %%
#training algorithms. They change the network!
def GD(net, X, Y, alpha=1e-4, max_iters=1000000, tolerance=1e-6):
    """
    Simple batch gradient descent
    """
    old_L = np.inf
    for i in xrange(max_iters):
        L, O, gradients = net.get_cost_and_gradient(X, Y)
        if old_L < L:
            print "Iter: %d, loss increased!!" % (i,)
        if (old_L - L)<tolerance:
            print "Tolerance level reached exiting"
            break
        if i % 1000 == 0:
            err_rate = (O.argmax(0) != Y).mean()
            print "At iteration %d, loss %f, train error rate %f%%" % (i, L, err_rate*100)
        for P,G in zip(net.parameters, gradients):
            P -= alpha * G
        old_L = L

# %%
from sklearn import datasets
iris = datasets.load_iris()
IrisX = iris.data.T
IrisX = (IrisX - IrisX.mean(axis=1, keepdims=True)) / IrisX.std(axis=1, keepdims=True)
IrisY = iris.target.reshape(1,-1)

# %%
#
# Here we verify that the network can be trained on Irises.
# Most runs should result in 100% accurracy
#

net = FeedForwardNet([
        AffineLayer(4,10),
        TanhLayer(),
        AffineLayer(10,3),
        SoftMaxLayer()
        ])
GD(net, IrisX,IrisY, 1e-1, tolerance=1e-7, max_iters=50000)
# Out:
# At iteration 0, loss 5.164703, train error rate 86.000000%
# At iteration 1000, loss 0.050033, train error rate 2.000000%
# At iteration 2000, loss 0.041009, train error rate 1.333333%
# At iteration 3000, loss 0.037605, train error rate 1.333333%
# At iteration 4000, loss 0.035378, train error rate 1.333333%
# At iteration 5000, loss 0.033415, train error rate 1.333333%
# At iteration 6000, loss 0.031366, train error rate 1.333333%
# At iteration 7000, loss 0.029075, train error rate 1.333333%
# At iteration 8000, loss 0.026538, train error rate 1.333333%
# At iteration 9000, loss 0.023901, train error rate 0.666667%
# At iteration 10000, loss 0.021374, train error rate 0.666667%
# At iteration 11000, loss 0.019099, train error rate 0.666667%
# At iteration 12000, loss 0.017116, train error rate 0.666667%
# At iteration 13000, loss 0.015404, train error rate 0.000000%
# At iteration 14000, loss 0.013923, train error rate 0.000000%
# At iteration 15000, loss 0.012633, train error rate 0.000000%
# At iteration 16000, loss 0.011498, train error rate 0.000000%
# At iteration 17000, loss 0.010482, train error rate 0.000000%
# At iteration 18000, loss 0.009550, train error rate 0.000000%
# At iteration 19000, loss 0.008677, train error rate 0.000000%
# At iteration 20000, loss 0.007876, train error rate 0.000000%
# At iteration 21000, loss 0.007178, train error rate 0.000000%
# At iteration 22000, loss 0.006585, train error rate 0.000000%
# At iteration 23000, loss 0.006079, train error rate 0.000000%
# At iteration 24000, loss 0.005641, train error rate 0.000000%
# At iteration 25000, loss 0.005258, train error rate 0.000000%
# At iteration 26000, loss 0.004920, train error rate 0.000000%
# At iteration 27000, loss 0.004619, train error rate 0.000000%
# At iteration 28000, loss 0.004348, train error rate 0.000000%
# At iteration 29000, loss 0.004103, train error rate 0.000000%
# At iteration 30000, loss 0.003881, train error rate 0.000000%
# At iteration 31000, loss 0.003679, train error rate 0.000000%
# At iteration 32000, loss 0.003494, train error rate 0.000000%
# At iteration 33000, loss 0.003324, train error rate 0.000000%
# At iteration 34000, loss 0.003168, train error rate 0.000000%
# At iteration 35000, loss 0.003024, train error rate 0.000000%
# At iteration 36000, loss 0.002892, train error rate 0.000000%
# At iteration 37000, loss 0.002769, train error rate 0.000000%
# At iteration 38000, loss 0.002656, train error rate 0.000000%
# At iteration 39000, loss 0.002551, train error rate 0.000000%
# Tolerance level reached exiting

# %% [markdown]
# ## Reading data from Fuel
#
# The following cell prepares the data pipeline in fuel. please see SGD template for usage example

# %%
from fuel.datasets.mnist import MNIST
from fuel.transformers import ScaleAndShift, Cast, Flatten, Mapping
from fuel.streams import DataStream
from fuel.schemes import SequentialScheme, ShuffledScheme

MNIST.default_transformers = (
    (ScaleAndShift, [2.0 / 255.0, -1], {'which_sources': 'features'}),
    (Cast, [np.float32], {'which_sources': 'features'}), 
    (Flatten, [], {'which_sources': 'features'}),
    (Mapping, [lambda batch: (b.T for b in batch)], {}) )

mnist_train = MNIST(("train",), subset=slice(None,50000))
#this stream will shuffle the MNIST set and return us batches of 100 examples
mnist_train_stream = DataStream.default_stream(
    mnist_train,
    iteration_scheme=ShuffledScheme(mnist_train.num_examples, 100))
                                               
mnist_validation = MNIST(("train",), subset=slice(50000, None))

# We will use larger portions for testing and validation
# as these dont do a backward pass and reauire less RAM.
mnist_validation_stream = DataStream.default_stream(
    mnist_validation, iteration_scheme=SequentialScheme(mnist_validation.num_examples, 250))
mnist_test = MNIST(("test",))
mnist_test_stream = DataStream.default_stream(
    mnist_test, iteration_scheme=SequentialScheme(mnist_test.num_examples, 250))

# %%
print "The streams return batches containing %s" % (mnist_train_stream.sources,)

print "Each trainin batch consits of a tuple containing:"
for element in next(mnist_train_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
    
print "Validation/test batches consits of tuples containing:"
for element in next(mnist_test_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
# Out:
# The streams return batches containing (u'features', u'targets')
# Each trainin batch consits of a tuple containing:
#  - an array of size (784, 100) containing float32
#  - an array of size (1, 100) containing uint8
# Validation/test batches consits of tuples containing:
#  - an array of size (784, 250) containing float32
#  - an array of size (1, 250) containing uint8

# %% [markdown]
# # Problem 1 [4p]
#
# Implement the following additions to the SGD code below:
# 1. Momentum [2p]
# 2. Learning rate schedule [1p]
# 3. Weight decay [1p]. One way to implement it is to use the functions `net.params` and `net.param_names` to get all parameters whose names are "W" and not "b".

# %%
#
# Please note, the code blow is able to train a SoftMax regression model on mnist to poor results (ca 8%test error), 
# you must improve it
#

from copy import deepcopy

def compute_error_rate(net, stream):
    num_errs = 0.0
    num_examples = 0
    for X, Y in stream.get_epoch_iterator():
        O = net.fprop(X)
        num_errs += (O.argmax(0) != Y).sum()
        num_examples += X.shape[1]
    return num_errs/num_examples

def SGD(net, train_stream, validation_stream, test_stream):
    i=0
    e=0
    
    #initialize momentum variables
    #
    # TODO
    #
    # Hint: you need one valocity matrix for each parameter
    # velocities = [None for P in net.parameters]
    velocities = [np.zeros_like(P) for P in net.parameters]
    
    best_valid_error_rate = np.inf
    best_params = deepcopy(net.parameters)
    best_params_epoch = 0
    
    train_erros = []
    train_loss = []
    validation_errors = []

    number_of_epochs = 3
    patience_expansion = 1.5
    
    try:
        while e<number_of_epochs: #This loop goes over epochs
            e += 1
            #First train on all data from this batch
            for X,Y in train_stream.get_epoch_iterator(): 
                i += 1
                L, O, gradients = net.get_cost_and_gradient(X, Y)
                err_rate = (O.argmax(0) != Y).mean()
                train_loss.append((i,L))
                train_erros.append((i,err_rate))
                if i % 100 == 0:
                    print "At minibatch %d, batch loss %f, batch error rate %f%%" % (i, L, err_rate*100)
                for P, V, G, N in zip(net.parameters, velocities, gradients, net.parameter_names):
                    if N=='W':
                        #
                        # TODO: implement the weight decay addition to gradient
                        #
                        #G += TODO
                        G += 1e-5 * P
                        
                    
                    #
                    # TODO: set a learning rate
                    #
                    # Hint, use the iteration counter i
                    # alpha = TODO
                    alpha = 1e+3 / (1e+4 + i)
                    
                    #
                    # TODO: set the momentum constant 
                    # epsilon = TODO
                    #
                    # epsilon = 0.5 if val_error_rate > 0.03 else 1.0
                    epsilon = 0.95

                    
                    #
                    # TODO: implement velocity update in momentum
                    # V[...] = TODO
                    #
                    V = epsilon * V + alpha * G
                    
                    #
                    # TODO: set a more sensible learning rule here,
                    # using your learning rate schedule and momentum
                    #
                    #!!!!! Need to modify the actual parameter here! 
                    # P += -5e-2 * G
                    P -= V
            # After an epoch compute validation error
            val_error_rate = compute_error_rate(net, validation_stream)
            if val_error_rate < best_valid_error_rate:
                number_of_epochs = np.maximum(number_of_epochs, e * patience_expansion+1)
                best_valid_error_rate = val_error_rate
                best_params = deepcopy(net.parameters)
                best_params_epoch = e
                validation_errors.append((i,val_error_rate))
            print "After epoch %d: valid_err_rate: %f%% currently going ot do %d epochs" %(
                e, val_error_rate, number_of_epochs)
            
    except KeyboardInterrupt:
        print "Setting network parameters from after epoch %d" %(best_params_epoch)
        net.parameters = best_params
        
    subplot(2,1,1)
    train_loss = np.array(train_loss)
    semilogy(train_loss[:,0], train_loss[:,1], label='batch train loss')
    legend()

    subplot(2,1,2)
    train_erros = np.array(train_erros)
    plot(train_erros[:,0], train_erros[:,1], label='batch train error rate')
    validation_errors = np.array(validation_errors)
    plot(validation_errors[:,0], validation_errors[:,1], label='validation error rate', color='r')
    ylim(0,0.2)
    legend()

# %% [markdown]
# # Problem 2 [5p]
#
# Tune the following network to reach below 1.9% error rate on
# the validation set. This should result in a test error below 2%. To
# tune the network you will need to:
# 1. choose the number of layers (more than 1, less than 5),
# 2. choose the number of neurons in each layer (more than 100,
#     less than 5000),
# 3. pick proper weight initialization,
# 4. pick proper learning rate schedule (need to decay over time,
#     good range to check on MNIST is about 1e-2 ... 1e-1 at the beginning and
#     half of that after 10000 batches),
# 5. pick a momentum constant (probably a constant one will be OK).

# %%
#
# TODO: pick a network architecture here. The one below is just 
# softmax regression
#

net = FeedForwardNet([
        AffineLayer(784,1000, weight_init=IsotropicGaussian(std=1.0/30.0)),
        TanhLayer(),
        AffineLayer(1000,10, weight_init=IsotropicGaussian(std=1.0/30.0)),
        SoftMaxLayer()
        ])
SGD(net, mnist_train_stream, mnist_validation_stream, mnist_test_stream)

print "Test error rate: %f" % (compute_error_rate(net, mnist_test_stream), )
# Out:
# At minibatch 100, batch loss 0.411660, batch error rate 12.000000%
# At minibatch 200, batch loss 0.425248, batch error rate 12.000000%
# At minibatch 300, batch loss 0.385698, batch error rate 12.000000%
# At minibatch 400, batch loss 0.377244, batch error rate 10.000000%
# At minibatch 500, batch loss 0.382788, batch error rate 11.000000%
# After epoch 1: valid_err_rate: 0.084400% currently going ot do 3 epochs
# At minibatch 600, batch loss 0.249778, batch error rate 8.000000%
# At minibatch 700, batch loss 0.267855, batch error rate 6.000000%
# At minibatch 800, batch loss 0.224628, batch error rate 8.000000%
# At minibatch 900, batch loss 0.379849, batch error rate 13.000000%
# At minibatch 1000, batch loss 0.315573, batch error rate 9.000000%
# After epoch 2: valid_err_rate: 0.064700% currently going ot do 4 epochs
# At minibatch 1100, batch loss 0.405899, batch error rate 13.000000%
# At minibatch 1200, batch loss 0.246134, batch error rate 7.000000%
# At minibatch 1300, batch loss 0.160679, batch error rate 6.000000%
# At minibatch 1400, batch loss 0.124855, batch error rate 2.000000%
# At minibatch 1500, batch loss 0.144475, batch error rate 5.000000%
# After epoch 3: valid_err_rate: 0.051800% currently going ot do 5 epochs
# At minibatch 1600, batch loss 0.190842, batch error rate 4.000000%
# At minibatch 1700, batch loss 0.089505, batch error rate 2.000000%
# At minibatch 1800, batch loss 0.078200, batch error rate 1.000000%
# At minibatch 1900, batch loss 0.196024, batch error rate 4.000000%
# At minibatch 2000, batch loss 0.074458, batch error rate 2.000000%
# After epoch 4: valid_err_rate: 0.046400% currently going ot do 7 epochs
# At minibatch 2100, batch loss 0.319312, batch error rate 12.000000%
# At minibatch 2200, batch loss 0.120951, batch error rate 3.000000%
# At minibatch 2300, batch loss 0.129368, batch error rate 2.000000%
# At minibatch 2400, batch loss 0.110145, batch error rate 4.000000%
# At minibatch 2500, batch loss 0.091884, batch error rate 2.000000%
# After epoch 5: valid_err_rate: 0.038000% currently going ot do 8 epochs
# At minibatch 2600, batch loss 0.105817, batch error rate 3.000000%
# At minibatch 2700, batch loss 0.075040, batch error rate 2.000000%
# At minibatch 2800, batch loss 0.089355, batch error rate 3.000000%
# At minibatch 2900, batch loss 0.098613, batch error rate 5.000000%
# At minibatch 3000, batch loss 0.099491, batch error rate 4.000000%
# After epoch 6: valid_err_rate: 0.033100% currently going ot do 10 epochs
# At minibatch 3100, batch loss 0.131987, batch error rate 6.000000%
# At minibatch 3200, batch loss 0.136973, batch error rate 5.000000%
# At minibatch 3300, batch loss 0.089059, batch error rate 4.000000%
# At minibatch 3400, batch loss 0.053488, batch error rate 1.000000%
# At minibatch 3500, batch loss 0.091490, batch error rate 2.000000%
# After epoch 7: valid_err_rate: 0.031400% currently going ot do 11 epochs
# At minibatch 3600, batch loss 0.136987, batch error rate 4.000000%
# At minibatch 3700, batch loss 0.192882, batch error rate 4.000000%
# At minibatch 3800, batch loss 0.078126, batch error rate 3.000000%
# At minibatch 3900, batch loss 0.083894, batch error rate 2.000000%
# At minibatch 4000, batch loss 0.141067, batch error rate 3.000000%
# After epoch 8: valid_err_rate: 0.031100% currently going ot do 13 epochs
# At minibatch 4100, batch loss 0.145197, batch error rate 6.000000%
# At minibatch 4200, batch loss 0.062119, batch error rate 3.000000%
# At minibatch 4300, batch loss 0.091548, batch error rate 2.000000%
# At minibatch 4400, batch loss 0.075349, batch error rate 2.000000%
# At minibatch 4500, batch loss 0.164657, batch error rate 3.000000%
# After epoch 9: valid_err_rate: 0.030400% currently going ot do 14 epochs
# At minibatch 4600, batch loss 0.043118, batch error rate 1.000000%
# At minibatch 4700, batch loss 0.045437, batch error rate 0.000000%
# At minibatch 4800, batch loss 0.043171, batch error rate 1.000000%
# At minibatch 4900, batch loss 0.113178, batch error rate 4.000000%
# At minibatch 5000, batch loss 0.075250, batch error rate 3.000000%
# After epoch 10: valid_err_rate: 0.027300% currently going ot do 16 epochs
# At minibatch 5100, batch loss 0.094273, batch error rate 4.000000%
# At minibatch 5200, batch loss 0.078339, batch error rate 1.000000%
# At minibatch 5300, batch loss 0.089645, batch error rate 5.000000%
# At minibatch 5400, batch loss 0.049237, batch error rate 1.000000%
# At minibatch 5500, batch loss 0.127415, batch error rate 3.000000%
# After epoch 11: valid_err_rate: 0.026100% currently going ot do 17 epochs
# At minibatch 5600, batch loss 0.060865, batch error rate 2.000000%
# At minibatch 5700, batch loss 0.129159, batch error rate 5.000000%
# At minibatch 5800, batch loss 0.093519, batch error rate 3.000000%
# At minibatch 5900, batch loss 0.061907, batch error rate 2.000000%
# At minibatch 6000, batch loss 0.076802, batch error rate 2.000000%
# After epoch 12: valid_err_rate: 0.027500% currently going ot do 17 epochs
# At minibatch 6100, batch loss 0.030820, batch error rate 1.000000%
# At minibatch 6200, batch loss 0.039067, batch error rate 1.000000%
# At minibatch 6300, batch loss 0.048519, batch error rate 2.000000%
# At minibatch 6400, batch loss 0.055227, batch error rate 1.000000%
# At minibatch 6500, batch loss 0.060581, batch error rate 2.000000%
# After epoch 13: valid_err_rate: 0.025200% currently going ot do 20 epochs
# At minibatch 6600, batch loss 0.039915, batch error rate 0.000000%
# At minibatch 6700, batch loss 0.037673, batch error rate 0.000000%
# At minibatch 6800, batch loss 0.022485, batch error rate 0.000000%
# At minibatch 6900, batch loss 0.075876, batch error rate 3.000000%
# At minibatch 7000, batch loss 0.084524, batch error rate 2.000000%
# After epoch 14: valid_err_rate: 0.026700% currently going ot do 20 epochs
# At minibatch 7100, batch loss 0.050280, batch error rate 3.000000%
# At minibatch 7200, batch loss 0.016839, batch error rate 0.000000%
# At minibatch 7300, batch loss 0.058596, batch error rate 2.000000%
# At minibatch 7400, batch loss 0.029784, batch error rate 1.000000%
# At minibatch 7500, batch loss 0.039365, batch error rate 1.000000%
# After epoch 15: valid_err_rate: 0.024200% currently going ot do 23 epochs
# At minibatch 7600, batch loss 0.042839, batch error rate 2.000000%
# At minibatch 7700, batch loss 0.064072, batch error rate 1.000000%
# At minibatch 7800, batch loss 0.032831, batch error rate 1.000000%
# At minibatch 7900, batch loss 0.013739, batch error rate 0.000000%
# At minibatch 8000, batch loss 0.096686, batch error rate 3.000000%
# After epoch 16: valid_err_rate: 0.026500% currently going ot do 23 epochs
# At minibatch 8100, batch loss 0.019374, batch error rate 0.000000%
# At minibatch 8200, batch loss 0.082213, batch error rate 3.000000%
# At minibatch 8300, batch loss 0.047430, batch error rate 1.000000%
# At minibatch 8400, batch loss 0.032640, batch error rate 1.000000%
# At minibatch 8500, batch loss 0.028659, batch error rate 0.000000%
# After epoch 17: valid_err_rate: 0.023200% currently going ot do 26 epochs
# At minibatch 8600, batch loss 0.023019, batch error rate 0.000000%
# At minibatch 8700, batch loss 0.024722, batch error rate 1.000000%
# At minibatch 8800, batch loss 0.073610, batch error rate 2.000000%
# At minibatch 8900, batch loss 0.015986, batch error rate 0.000000%
# At minibatch 9000, batch loss 0.058063, batch error rate 1.000000%
# After epoch 18: valid_err_rate: 0.024200% currently going ot do 26 epochs
# At minibatch 9100, batch loss 0.070113, batch error rate 3.000000%
# At minibatch 9200, batch loss 0.026593, batch error rate 1.000000%
# At minibatch 9300, batch loss 0.024374, batch error rate 0.000000%
# At minibatch 9400, batch loss 0.036524, batch error rate 1.000000%
# At minibatch 9500, batch loss 0.046067, batch error rate 1.000000%
# After epoch 19: valid_err_rate: 0.022900% currently going ot do 29 epochs
# At minibatch 9600, batch loss 0.025020, batch error rate 1.000000%
# At minibatch 9700, batch loss 0.040788, batch error rate 1.000000%
# At minibatch 9800, batch loss 0.035510, batch error rate 0.000000%
# At minibatch 9900, batch loss 0.069376, batch error rate 4.000000%
# At minibatch 10000, batch loss 0.072086, batch error rate 2.000000%
# After epoch 20: valid_err_rate: 0.023100% currently going ot do 29 epochs
# At minibatch 10100, batch loss 0.058632, batch error rate 1.000000%
# At minibatch 10200, batch loss 0.016830, batch error rate 0.000000%
# At minibatch 10300, batch loss 0.029417, batch error rate 0.000000%
# At minibatch 10400, batch loss 0.020251, batch error rate 0.000000%
# At minibatch 10500, batch loss 0.026152, batch error rate 0.000000%
# After epoch 21: valid_err_rate: 0.021400% currently going ot do 32 epochs
# At minibatch 10600, batch loss 0.022222, batch error rate 0.000000%
# At minibatch 10700, batch loss 0.016965, batch error rate 1.000000%
# At minibatch 10800, batch loss 0.018395, batch error rate 1.000000%
# At minibatch 10900, batch loss 0.038152, batch error rate 1.000000%
# At minibatch 11000, batch loss 0.012063, batch error rate 0.000000%
# After epoch 22: valid_err_rate: 0.021900% currently going ot do 32 epochs
# At minibatch 11100, batch loss 0.029637, batch error rate 1.000000%
# At minibatch 11200, batch loss 0.091811, batch error rate 4.000000%
# At minibatch 11300, batch loss 0.048196, batch error rate 2.000000%
# At minibatch 11400, batch loss 0.025770, batch error rate 1.000000%
# At minibatch 11500, batch loss 0.034145, batch error rate 2.000000%
# After epoch 23: valid_err_rate: 0.022100% currently going ot do 32 epochs
# At minibatch 11600, batch loss 0.015810, batch error rate 0.000000%
# At minibatch 11700, batch loss 0.016985, batch error rate 0.000000%
# At minibatch 11800, batch loss 0.032491, batch error rate 0.000000%
# At minibatch 11900, batch loss 0.032579, batch error rate 1.000000%
# At minibatch 12000, batch loss 0.026253, batch error rate 1.000000%
# After epoch 24: valid_err_rate: 0.021600% currently going ot do 32 epochs
# At minibatch 12100, batch loss 0.024302, batch error rate 1.000000%
# At minibatch 12200, batch loss 0.049722, batch error rate 1.000000%
# At minibatch 12300, batch loss 0.015028, batch error rate 0.000000%
# At minibatch 12400, batch loss 0.020800, batch error rate 0.000000%
# At minibatch 12500, batch loss 0.018817, batch error rate 0.000000%
# After epoch 25: valid_err_rate: 0.022700% currently going ot do 32 epochs
# At minibatch 12600, batch loss 0.034691, batch error rate 2.000000%
# At minibatch 12700, batch loss 0.035762, batch error rate 1.000000%
# At minibatch 12800, batch loss 0.019022, batch error rate 0.000000%
# At minibatch 12900, batch loss 0.022495, batch error rate 0.000000%
# At minibatch 13000, batch loss 0.027687, batch error rate 0.000000%
# After epoch 26: valid_err_rate: 0.022000% currently going ot do 32 epochs
# At minibatch 13100, batch loss 0.018505, batch error rate 1.000000%
# At minibatch 13200, batch loss 0.026170, batch error rate 1.000000%
# At minibatch 13300, batch loss 0.037452, batch error rate 1.000000%
# At minibatch 13400, batch loss 0.044570, batch error rate 1.000000%
# At minibatch 13500, batch loss 0.024658, batch error rate 0.000000%
# After epoch 27: valid_err_rate: 0.021500% currently going ot do 32 epochs
# At minibatch 13600, batch loss 0.036135, batch error rate 2.000000%
# At minibatch 13700, batch loss 0.062148, batch error rate 2.000000%
# At minibatch 13800, batch loss 0.031405, batch error rate 1.000000%
# At minibatch 13900, batch loss 0.010762, batch error rate 0.000000%
# At minibatch 14000, batch loss 0.053197, batch error rate 1.000000%
# After epoch 28: valid_err_rate: 0.021900% currently going ot do 32 epochs
# At minibatch 14100, batch loss 0.020072, batch error rate 0.000000%
# At minibatch 14200, batch loss 0.023889, batch error rate 0.000000%
# At minibatch 14300, batch loss 0.004747, batch error rate 0.000000%
# At minibatch 14400, batch loss 0.097787, batch error rate 2.000000%
# At minibatch 14500, batch loss 0.021089, batch error rate 0.000000%
# After epoch 29: valid_err_rate: 0.021400% currently going ot do 32 epochs
# At minibatch 14600, batch loss 0.009287, batch error rate 0.000000%
# At minibatch 14700, batch loss 0.034246, batch error rate 1.000000%
# At minibatch 14800, batch loss 0.031865, batch error rate 3.000000%
# At minibatch 14900, batch loss 0.027020, batch error rate 1.000000%
# At minibatch 15000, batch loss 0.038740, batch error rate 0.000000%
# After epoch 30: valid_err_rate: 0.021600% currently going ot do 32 epochs
# At minibatch 15100, batch loss 0.029418, batch error rate 1.000000%
# At minibatch 15200, batch loss 0.015826, batch error rate 0.000000%
# At minibatch 15300, batch loss 0.078711, batch error rate 2.000000%
# At minibatch 15400, batch loss 0.013832, batch error rate 0.000000%
# At minibatch 15500, batch loss 0.013088, batch error rate 0.000000%
# After epoch 31: valid_err_rate: 0.021300% currently going ot do 47 epochs
# At minibatch 15600, batch loss 0.010452, batch error rate 0.000000%
# At minibatch 15700, batch loss 0.016841, batch error rate 0.000000%
# At minibatch 15800, batch loss 0.019238, batch error rate 1.000000%
# At minibatch 15900, batch loss 0.011078, batch error rate 0.000000%
# At minibatch 16000, batch loss 0.005460, batch error rate 0.000000%
# After epoch 32: valid_err_rate: 0.020700% currently going ot do 49 epochs
# At minibatch 16100, batch loss 0.022521, batch error rate 0.000000%
# At minibatch 16200, batch loss 0.012072, batch error rate 0.000000%
# At minibatch 16300, batch loss 0.010082, batch error rate 0.000000%
# At minibatch 16400, batch loss 0.008689, batch error rate 0.000000%
# At minibatch 16500, batch loss 0.007622, batch error rate 0.000000%
# After epoch 33: valid_err_rate: 0.021200% currently going ot do 49 epochs
# At minibatch 16600, batch loss 0.008471, batch error rate 0.000000%
# At minibatch 16700, batch loss 0.022881, batch error rate 0.000000%
# At minibatch 16800, batch loss 0.018930, batch error rate 0.000000%
# At minibatch 16900, batch loss 0.011929, batch error rate 0.000000%
# At minibatch 17000, batch loss 0.018969, batch error rate 0.000000%
# After epoch 34: valid_err_rate: 0.020500% currently going ot do 52 epochs
# At minibatch 17100, batch loss 0.026680, batch error rate 0.000000%
# At minibatch 17200, batch loss 0.017501, batch error rate 0.000000%
# At minibatch 17300, batch loss 0.036955, batch error rate 1.000000%
# At minibatch 17400, batch loss 0.010305, batch error rate 0.000000%
# At minibatch 17500, batch loss 0.022136, batch error rate 0.000000%
# After epoch 35: valid_err_rate: 0.020300% currently going ot do 53 epochs
# At minibatch 17600, batch loss 0.009367, batch error rate 0.000000%
# At minibatch 17700, batch loss 0.010241, batch error rate 0.000000%
# At minibatch 17800, batch loss 0.017321, batch error rate 0.000000%
# At minibatch 17900, batch loss 0.008631, batch error rate 0.000000%
# At minibatch 18000, batch loss 0.012747, batch error rate 0.000000%
# After epoch 36: valid_err_rate: 0.020500% currently going ot do 53 epochs
# At minibatch 18100, batch loss 0.010395, batch error rate 0.000000%
# At minibatch 18200, batch loss 0.017411, batch error rate 0.000000%
# At minibatch 18300, batch loss 0.019345, batch error rate 0.000000%
# At minibatch 18400, batch loss 0.012420, batch error rate 0.000000%
# At minibatch 18500, batch loss 0.003972, batch error rate 0.000000%
# After epoch 37: valid_err_rate: 0.020500% currently going ot do 53 epochs
# At minibatch 18600, batch loss 0.049878, batch error rate 1.000000%
# At minibatch 18700, batch loss 0.023473, batch error rate 0.000000%
# At minibatch 18800, batch loss 0.018934, batch error rate 0.000000%
# At minibatch 18900, batch loss 0.014297, batch error rate 0.000000%
# At minibatch 19000, batch loss 0.007965, batch error rate 0.000000%
# After epoch 38: valid_err_rate: 0.021100% currently going ot do 53 epochs
# At minibatch 19100, batch loss 0.042241, batch error rate 1.000000%
# At minibatch 19200, batch loss 0.029136, batch error rate 1.000000%
# At minibatch 19300, batch loss 0.014523, batch error rate 0.000000%
# At minibatch 19400, batch loss 0.027219, batch error rate 1.000000%
# At minibatch 19500, batch loss 0.009817, batch error rate 0.000000%
# After epoch 39: valid_err_rate: 0.020300% currently going ot do 53 epochs
# At minibatch 19600, batch loss 0.012515, batch error rate 0.000000%
# At minibatch 19700, batch loss 0.008406, batch error rate 0.000000%
# At minibatch 19800, batch loss 0.037868, batch error rate 1.000000%
# At minibatch 19900, batch loss 0.052493, batch error rate 2.000000%
# At minibatch 20000, batch loss 0.004193, batch error rate 0.000000%
# After epoch 40: valid_err_rate: 0.021000% currently going ot do 53 epochs
# At minibatch 20100, batch loss 0.014177, batch error rate 0.000000%
# At minibatch 20200, batch loss 0.015453, batch error rate 0.000000%
# At minibatch 20300, batch loss 0.007381, batch error rate 0.000000%
# At minibatch 20400, batch loss 0.022482, batch error rate 1.000000%
# At minibatch 20500, batch loss 0.015248, batch error rate 0.000000%
# After epoch 41: valid_err_rate: 0.021400% currently going ot do 53 epochs
# At minibatch 20600, batch loss 0.020415, batch error rate 0.000000%
# At minibatch 20700, batch loss 0.025043, batch error rate 0.000000%
# At minibatch 20800, batch loss 0.008131, batch error rate 0.000000%
# At minibatch 20900, batch loss 0.010870, batch error rate 0.000000%
# At minibatch 21000, batch loss 0.009616, batch error rate 0.000000%
# After epoch 42: valid_err_rate: 0.020000% currently going ot do 64 epochs
# At minibatch 21100, batch loss 0.020141, batch error rate 0.000000%
# At minibatch 21200, batch loss 0.025057, batch error rate 1.000000%
# At minibatch 21300, batch loss 0.010557, batch error rate 0.000000%
# At minibatch 21400, batch loss 0.006800, batch error rate 0.000000%
# At minibatch 21500, batch loss 0.014644, batch error rate 1.000000%
# After epoch 43: valid_err_rate: 0.020200% currently going ot do 64 epochs
# At minibatch 21600, batch loss 0.017488, batch error rate 0.000000%
# At minibatch 21700, batch loss 0.006279, batch error rate 0.000000%
# At minibatch 21800, batch loss 0.032049, batch error rate 0.000000%
# At minibatch 21900, batch loss 0.017492, batch error rate 0.000000%
# At minibatch 22000, batch loss 0.013223, batch error rate 0.000000%
# After epoch 44: valid_err_rate: 0.020800% currently going ot do 64 epochs
# At minibatch 22100, batch loss 0.025012, batch error rate 0.000000%
# At minibatch 22200, batch loss 0.008680, batch error rate 0.000000%
# At minibatch 22300, batch loss 0.012723, batch error rate 0.000000%
# At minibatch 22400, batch loss 0.022621, batch error rate 1.000000%
# At minibatch 22500, batch loss 0.014410, batch error rate 1.000000%
# After epoch 45: valid_err_rate: 0.020700% currently going ot do 64 epochs
# At minibatch 22600, batch loss 0.014009, batch error rate 0.000000%
# At minibatch 22700, batch loss 0.010571, batch error rate 0.000000%
# At minibatch 22800, batch loss 0.020399, batch error rate 1.000000%
# At minibatch 22900, batch loss 0.019312, batch error rate 1.000000%
# At minibatch 23000, batch loss 0.018855, batch error rate 1.000000%
# After epoch 46: valid_err_rate: 0.020600% currently going ot do 64 epochs
# At minibatch 23100, batch loss 0.004428, batch error rate 0.000000%
# At minibatch 23200, batch loss 0.013021, batch error rate 0.000000%
# At minibatch 23300, batch loss 0.011536, batch error rate 0.000000%
# At minibatch 23400, batch loss 0.025730, batch error rate 1.000000%
# At minibatch 23500, batch loss 0.008466, batch error rate 0.000000%
# After epoch 47: valid_err_rate: 0.020000% currently going ot do 64 epochs
# At minibatch 23600, batch loss 0.003883, batch error rate 0.000000%
# At minibatch 23700, batch loss 0.006968, batch error rate 0.000000%
# At minibatch 23800, batch loss 0.013886, batch error rate 0.000000%
# At minibatch 23900, batch loss 0.020011, batch error rate 0.000000%
# At minibatch 24000, batch loss 0.015191, batch error rate 0.000000%
# After epoch 48: valid_err_rate: 0.020400% currently going ot do 64 epochs
# At minibatch 24100, batch loss 0.011181, batch error rate 0.000000%
# At minibatch 24200, batch loss 0.008790, batch error rate 0.000000%
# At minibatch 24300, batch loss 0.009381, batch error rate 0.000000%
# At minibatch 24400, batch loss 0.010296, batch error rate 0.000000%
# At minibatch 24500, batch loss 0.005661, batch error rate 0.000000%
# After epoch 49: valid_err_rate: 0.020100% currently going ot do 64 epochs
# At minibatch 24600, batch loss 0.048031, batch error rate 1.000000%
# At minibatch 24700, batch loss 0.010438, batch error rate 0.000000%
# At minibatch 24800, batch loss 0.007621, batch error rate 0.000000%
# At minibatch 24900, batch loss 0.024703, batch error rate 0.000000%
# At minibatch 25000, batch loss 0.011274, batch error rate 0.000000%
# After epoch 50: valid_err_rate: 0.020200% currently going ot do 64 epochs
# At minibatch 25100, batch loss 0.011122, batch error rate 0.000000%
# At minibatch 25200, batch loss 0.003928, batch error rate 0.000000%
# At minibatch 25300, batch loss 0.011597, batch error rate 0.000000%
# At minibatch 25400, batch loss 0.011131, batch error rate 0.000000%
# At minibatch 25500, batch loss 0.017301, batch error rate 0.000000%
# After epoch 51: valid_err_rate: 0.020200% currently going ot do 64 epochs
# At minibatch 25600, batch loss 0.008835, batch error rate 0.000000%
# At minibatch 25700, batch loss 0.011346, batch error rate 0.000000%
# At minibatch 25800, batch loss 0.012262, batch error rate 0.000000%
# At minibatch 25900, batch loss 0.010988, batch error rate 0.000000%
# At minibatch 26000, batch loss 0.006908, batch error rate 0.000000%
# After epoch 52: valid_err_rate: 0.020200% currently going ot do 64 epochs
# At minibatch 26100, batch loss 0.020238, batch error rate 1.000000%
# At minibatch 26200, batch loss 0.006139, batch error rate 0.000000%
# At minibatch 26300, batch loss 0.010135, batch error rate 0.000000%
# At minibatch 26400, batch loss 0.020630, batch error rate 1.000000%
# At minibatch 26500, batch loss 0.022145, batch error rate 1.000000%
# After epoch 53: valid_err_rate: 0.020300% currently going ot do 64 epochs
# At minibatch 26600, batch loss 0.019158, batch error rate 0.000000%
# At minibatch 26700, batch loss 0.006311, batch error rate 0.000000%
# At minibatch 26800, batch loss 0.021081, batch error rate 1.000000%
# At minibatch 26900, batch loss 0.018320, batch error rate 0.000000%
# At minibatch 27000, batch loss 0.008033, batch error rate 0.000000%
# After epoch 54: valid_err_rate: 0.020400% currently going ot do 64 epochs
# At minibatch 27100, batch loss 0.008852, batch error rate 0.000000%
# At minibatch 27200, batch loss 0.007343, batch error rate 0.000000%
# At minibatch 27300, batch loss 0.013040, batch error rate 0.000000%
# At minibatch 27400, batch loss 0.014368, batch error rate 0.000000%
# At minibatch 27500, batch loss 0.010696, batch error rate 0.000000%
# After epoch 55: valid_err_rate: 0.020000% currently going ot do 64 epochs
# At minibatch 27600, batch loss 0.009545, batch error rate 0.000000%
# At minibatch 27700, batch loss 0.010087, batch error rate 0.000000%
# At minibatch 27800, batch loss 0.012861, batch error rate 0.000000%
# At minibatch 27900, batch loss 0.009161, batch error rate 0.000000%
# At minibatch 28000, batch loss 0.017806, batch error rate 0.000000%
# After epoch 56: valid_err_rate: 0.018700% currently going ot do 85 epochs
# At minibatch 28100, batch loss 0.005104, batch error rate 0.000000%
# At minibatch 28200, batch loss 0.006700, batch error rate 0.000000%
# At minibatch 28300, batch loss 0.008526, batch error rate 0.000000%
# At minibatch 28400, batch loss 0.009581, batch error rate 0.000000%
# At minibatch 28500, batch loss 0.028516, batch error rate 1.000000%
# After epoch 57: valid_err_rate: 0.019800% currently going ot do 85 epochs
# At minibatch 28600, batch loss 0.010345, batch error rate 0.000000%
# At minibatch 28700, batch loss 0.018323, batch error rate 1.000000%
# At minibatch 28800, batch loss 0.004007, batch error rate 0.000000%
# At minibatch 28900, batch loss 0.005665, batch error rate 0.000000%
# At minibatch 29000, batch loss 0.013401, batch error rate 0.000000%
# After epoch 58: valid_err_rate: 0.020300% currently going ot do 85 epochs
# At minibatch 29100, batch loss 0.009969, batch error rate 0.000000%
# At minibatch 29200, batch loss 0.010127, batch error rate 0.000000%
# At minibatch 29300, batch loss 0.008655, batch error rate 0.000000%
# At minibatch 29400, batch loss 0.042668, batch error rate 1.000000%
# At minibatch 29500, batch loss 0.005036, batch error rate 0.000000%
# After epoch 59: valid_err_rate: 0.019100% currently going ot do 85 epochs
# At minibatch 29600, batch loss 0.003155, batch error rate 0.000000%
# At minibatch 29700, batch loss 0.008595, batch error rate 0.000000%
# At minibatch 29800, batch loss 0.011917, batch error rate 0.000000%
# At minibatch 29900, batch loss 0.005273, batch error rate 0.000000%
# At minibatch 30000, batch loss 0.010567, batch error rate 0.000000%
# After epoch 60: valid_err_rate: 0.019800% currently going ot do 85 epochs
# At minibatch 30100, batch loss 0.010371, batch error rate 0.000000%
# At minibatch 30200, batch loss 0.024325, batch error rate 1.000000%
# At minibatch 30300, batch loss 0.007272, batch error rate 0.000000%
# At minibatch 30400, batch loss 0.008283, batch error rate 0.000000%
# At minibatch 30500, batch loss 0.008829, batch error rate 0.000000%
# After epoch 61: valid_err_rate: 0.019700% currently going ot do 85 epochs
# At minibatch 30600, batch loss 0.011269, batch error rate 0.000000%
# At minibatch 30700, batch loss 0.023112, batch error rate 1.000000%
# At minibatch 30800, batch loss 0.015418, batch error rate 0.000000%
# At minibatch 30900, batch loss 0.009948, batch error rate 0.000000%
# At minibatch 31000, batch loss 0.004891, batch error rate 0.000000%
# After epoch 62: valid_err_rate: 0.020300% currently going ot do 85 epochs
# At minibatch 31100, batch loss 0.008321, batch error rate 0.000000%
# At minibatch 31200, batch loss 0.006849, batch error rate 0.000000%
# At minibatch 31300, batch loss 0.005206, batch error rate 0.000000%
# At minibatch 31400, batch loss 0.007347, batch error rate 0.000000%
# At minibatch 31500, batch loss 0.017539, batch error rate 1.000000%
# After epoch 63: valid_err_rate: 0.020100% currently going ot do 85 epochs
# At minibatch 31600, batch loss 0.012849, batch error rate 0.000000%
# At minibatch 31700, batch loss 0.005793, batch error rate 0.000000%
# At minibatch 31800, batch loss 0.007401, batch error rate 0.000000%
# At minibatch 31900, batch loss 0.021872, batch error rate 0.000000%
# At minibatch 32000, batch loss 0.010299, batch error rate 0.000000%
# After epoch 64: valid_err_rate: 0.019800% currently going ot do 85 epochs
# At minibatch 32100, batch loss 0.002896, batch error rate 0.000000%
# At minibatch 32200, batch loss 0.009469, batch error rate 0.000000%
# At minibatch 32300, batch loss 0.008120, batch error rate 0.000000%
# At minibatch 32400, batch loss 0.004056, batch error rate 0.000000%
# At minibatch 32500, batch loss 0.006738, batch error rate 0.000000%
# After epoch 65: valid_err_rate: 0.020100% currently going ot do 85 epochs
# At minibatch 32600, batch loss 0.017150, batch error rate 0.000000%
# At minibatch 32700, batch loss 0.005271, batch error rate 0.000000%
# At minibatch 32800, batch loss 0.021149, batch error rate 1.000000%
# At minibatch 32900, batch loss 0.005128, batch error rate 0.000000%
# At minibatch 33000, batch loss 0.005919, batch error rate 0.000000%
# After epoch 66: valid_err_rate: 0.019500% currently going ot do 85 epochs
# At minibatch 33100, batch loss 0.011411, batch error rate 0.000000%
# At minibatch 33200, batch loss 0.005743, batch error rate 0.000000%
# At minibatch 33300, batch loss 0.006890, batch error rate 0.000000%
# At minibatch 33400, batch loss 0.009516, batch error rate 0.000000%
# At minibatch 33500, batch loss 0.006680, batch error rate 0.000000%
# After epoch 67: valid_err_rate: 0.019800% currently going ot do 85 epochs
# At minibatch 33600, batch loss 0.014742, batch error rate 0.000000%
# At minibatch 33700, batch loss 0.008198, batch error rate 0.000000%
# At minibatch 33800, batch loss 0.003793, batch error rate 0.000000%
# At minibatch 33900, batch loss 0.007932, batch error rate 0.000000%
# At minibatch 34000, batch loss 0.014538, batch error rate 0.000000%
# After epoch 68: valid_err_rate: 0.019600% currently going ot do 85 epochs
# At minibatch 34100, batch loss 0.016856, batch error rate 0.000000%
# At minibatch 34200, batch loss 0.008157, batch error rate 0.000000%
# At minibatch 34300, batch loss 0.005341, batch error rate 0.000000%
# At minibatch 34400, batch loss 0.008486, batch error rate 0.000000%
# At minibatch 34500, batch loss 0.011715, batch error rate 0.000000%
# After epoch 69: valid_err_rate: 0.020100% currently going ot do 85 epochs
# At minibatch 34600, batch loss 0.007158, batch error rate 0.000000%
# At minibatch 34700, batch loss 0.004567, batch error rate 0.000000%
# At minibatch 34800, batch loss 0.006017, batch error rate 0.000000%
# At minibatch 34900, batch loss 0.013261, batch error rate 0.000000%
# At minibatch 35000, batch loss 0.027046, batch error rate 1.000000%
# After epoch 70: valid_err_rate: 0.019500% currently going ot do 85 epochs
# At minibatch 35100, batch loss 0.008899, batch error rate 0.000000%
# At minibatch 35200, batch loss 0.003687, batch error rate 0.000000%
# At minibatch 35300, batch loss 0.010582, batch error rate 0.000000%
# At minibatch 35400, batch loss 0.006821, batch error rate 0.000000%
# At minibatch 35500, batch loss 0.004825, batch error rate 0.000000%
# After epoch 71: valid_err_rate: 0.019900% currently going ot do 85 epochs
# At minibatch 35600, batch loss 0.015104, batch error rate 0.000000%
# At minibatch 35700, batch loss 0.007862, batch error rate 0.000000%
# At minibatch 35800, batch loss 0.006240, batch error rate 0.000000%
# At minibatch 35900, batch loss 0.008340, batch error rate 0.000000%
# At minibatch 36000, batch loss 0.007680, batch error rate 0.000000%
# After epoch 72: valid_err_rate: 0.019700% currently going ot do 85 epochs
# At minibatch 36100, batch loss 0.006156, batch error rate 0.000000%
# At minibatch 36200, batch loss 0.005621, batch error rate 0.000000%
# At minibatch 36300, batch loss 0.003655, batch error rate 0.000000%
# At minibatch 36400, batch loss 0.005309, batch error rate 0.000000%
# At minibatch 36500, batch loss 0.018174, batch error rate 0.000000%
# After epoch 73: valid_err_rate: 0.019500% currently going ot do 85 epochs
# At minibatch 36600, batch loss 0.012256, batch error rate 0.000000%
# At minibatch 36700, batch loss 0.005272, batch error rate 0.000000%
# At minibatch 36800, batch loss 0.004155, batch error rate 0.000000%
# At minibatch 36900, batch loss 0.003113, batch error rate 0.000000%
# At minibatch 37000, batch loss 0.008661, batch error rate 0.000000%
# After epoch 74: valid_err_rate: 0.019000% currently going ot do 85 epochs
# At minibatch 37100, batch loss 0.008553, batch error rate 0.000000%
# At minibatch 37200, batch loss 0.004090, batch error rate 0.000000%
# At minibatch 37300, batch loss 0.006084, batch error rate 0.000000%
# At minibatch 37400, batch loss 0.011500, batch error rate 0.000000%
# At minibatch 37500, batch loss 0.011087, batch error rate 0.000000%
# After epoch 75: valid_err_rate: 0.019200% currently going ot do 85 epochs
# At minibatch 37600, batch loss 0.004280, batch error rate 0.000000%
# At minibatch 37700, batch loss 0.012655, batch error rate 0.000000%
# At minibatch 37800, batch loss 0.011179, batch error rate 0.000000%
# At minibatch 37900, batch loss 0.013177, batch error rate 1.000000%
# At minibatch 38000, batch loss 0.004230, batch error rate 0.000000%
# After epoch 76: valid_err_rate: 0.019500% currently going ot do 85 epochs
# At minibatch 38100, batch loss 0.007634, batch error rate 0.000000%
# At minibatch 38200, batch loss 0.008714, batch error rate 0.000000%
# At minibatch 38300, batch loss 0.002814, batch error rate 0.000000%
# At minibatch 38400, batch loss 0.006143, batch error rate 0.000000%
# At minibatch 38500, batch loss 0.003487, batch error rate 0.000000%
# After epoch 77: valid_err_rate: 0.019800% currently going ot do 85 epochs
# At minibatch 38600, batch loss 0.009038, batch error rate 0.000000%
# At minibatch 38700, batch loss 0.009552, batch error rate 0.000000%
# At minibatch 38800, batch loss 0.012091, batch error rate 0.000000%
# At minibatch 38900, batch loss 0.006325, batch error rate 0.000000%
# At minibatch 39000, batch loss 0.010760, batch error rate 0.000000%
# After epoch 78: valid_err_rate: 0.019000% currently going ot do 85 epochs
# At minibatch 39100, batch loss 0.004154, batch error rate 0.000000%
# At minibatch 39200, batch loss 0.010132, batch error rate 0.000000%
# At minibatch 39300, batch loss 0.005218, batch error rate 0.000000%
# At minibatch 39400, batch loss 0.010132, batch error rate 0.000000%
# At minibatch 39500, batch loss 0.010966, batch error rate 0.000000%
# After epoch 79: valid_err_rate: 0.019400% currently going ot do 85 epochs
# At minibatch 39600, batch loss 0.010132, batch error rate 0.000000%
# At minibatch 39700, batch loss 0.011482, batch error rate 0.000000%
# At minibatch 39800, batch loss 0.003239, batch error rate 0.000000%
# At minibatch 39900, batch loss 0.007035, batch error rate 0.000000%
# At minibatch 40000, batch loss 0.004494, batch error rate 0.000000%
# After epoch 80: valid_err_rate: 0.019000% currently going ot do 85 epochs
# At minibatch 40100, batch loss 0.010301, batch error rate 0.000000%
# At minibatch 40200, batch loss 0.005139, batch error rate 0.000000%
# At minibatch 40300, batch loss 0.005354, batch error rate 0.000000%
# At minibatch 40400, batch loss 0.006439, batch error rate 0.000000%
# At minibatch 40500, batch loss 0.007286, batch error rate 0.000000%
# After epoch 81: valid_err_rate: 0.018800% currently going ot do 85 epochs
# At minibatch 40600, batch loss 0.011321, batch error rate 0.000000%
# At minibatch 40700, batch loss 0.008695, batch error rate 0.000000%
# At minibatch 40800, batch loss 0.009533, batch error rate 0.000000%
# At minibatch 40900, batch loss 0.013421, batch error rate 0.000000%
# At minibatch 41000, batch loss 0.006481, batch error rate 0.000000%
# After epoch 82: valid_err_rate: 0.019300% currently going ot do 85 epochs
# At minibatch 41100, batch loss 0.006286, batch error rate 0.000000%
# At minibatch 41200, batch loss 0.010300, batch error rate 0.000000%
# At minibatch 41300, batch loss 0.003112, batch error rate 0.000000%
# At minibatch 41400, batch loss 0.004156, batch error rate 0.000000%
# At minibatch 41500, batch loss 0.009802, batch error rate 0.000000%
# After epoch 83: valid_err_rate: 0.019400% currently going ot do 85 epochs
# At minibatch 41600, batch loss 0.003463, batch error rate 0.000000%
# At minibatch 41700, batch loss 0.008230, batch error rate 0.000000%
# At minibatch 41800, batch loss 0.013226, batch error rate 0.000000%
# At minibatch 41900, batch loss 0.007205, batch error rate 0.000000%
# At minibatch 42000, batch loss 0.018265, batch error rate 0.000000%
# After epoch 84: valid_err_rate: 0.019700% currently going ot do 85 epochs
# At minibatch 42100, batch loss 0.006945, batch error rate 0.000000%
# At minibatch 42200, batch loss 0.003735, batch error rate 0.000000%
# At minibatch 42300, batch loss 0.005093, batch error rate 0.000000%
# At minibatch 42400, batch loss 0.002968, batch error rate 0.000000%
# At minibatch 42500, batch loss 0.006203, batch error rate 0.000000%
# After epoch 85: valid_err_rate: 0.018600% currently going ot do 128 epochs
# At minibatch 42600, batch loss 0.002866, batch error rate 0.000000%
# At minibatch 42700, batch loss 0.006069, batch error rate 0.000000%
# At minibatch 42800, batch loss 0.005676, batch error rate 0.000000%
# At minibatch 42900, batch loss 0.003938, batch error rate 0.000000%
# At minibatch 43000, batch loss 0.005178, batch error rate 0.000000%
# After epoch 86: valid_err_rate: 0.018600% currently going ot do 128 epochs
# At minibatch 43100, batch loss 0.006652, batch error rate 0.000000%
# At minibatch 43200, batch loss 0.009238, batch error rate 0.000000%
# At minibatch 43300, batch loss 0.005651, batch error rate 0.000000%
# At minibatch 43400, batch loss 0.003428, batch error rate 0.000000%
# At minibatch 43500, batch loss 0.011727, batch error rate 0.000000%
# After epoch 87: valid_err_rate: 0.018900% currently going ot do 128 epochs
# At minibatch 43600, batch loss 0.016325, batch error rate 0.000000%
# At minibatch 43700, batch loss 0.012450, batch error rate 0.000000%
# At minibatch 43800, batch loss 0.005626, batch error rate 0.000000%
# At minibatch 43900, batch loss 0.009729, batch error rate 0.000000%
# At minibatch 44000, batch loss 0.009957, batch error rate 0.000000%
# After epoch 88: valid_err_rate: 0.019100% currently going ot do 128 epochs
# At minibatch 44100, batch loss 0.008994, batch error rate 0.000000%
# At minibatch 44200, batch loss 0.007326, batch error rate 0.000000%
# At minibatch 44300, batch loss 0.003576, batch error rate 0.000000%
# At minibatch 44400, batch loss 0.004118, batch error rate 0.000000%
# At minibatch 44500, batch loss 0.006121, batch error rate 0.000000%
# After epoch 89: valid_err_rate: 0.018900% currently going ot do 128 epochs
# At minibatch 44600, batch loss 0.006776, batch error rate 0.000000%
# At minibatch 44700, batch loss 0.015085, batch error rate 1.000000%
# At minibatch 44800, batch loss 0.004441, batch error rate 0.000000%
# At minibatch 44900, batch loss 0.007309, batch error rate 0.000000%
# At minibatch 45000, batch loss 0.005874, batch error rate 0.000000%
# After epoch 90: valid_err_rate: 0.019400% currently going ot do 128 epochs
# At minibatch 45100, batch loss 0.013378, batch error rate 1.000000%
# At minibatch 45200, batch loss 0.014805, batch error rate 0.000000%
# At minibatch 45300, batch loss 0.006687, batch error rate 0.000000%
# At minibatch 45400, batch loss 0.004923, batch error rate 0.000000%
# At minibatch 45500, batch loss 0.004808, batch error rate 0.000000%
# After epoch 91: valid_err_rate: 0.019100% currently going ot do 128 epochs
# At minibatch 45600, batch loss 0.007039, batch error rate 0.000000%
# At minibatch 45700, batch loss 0.004772, batch error rate 0.000000%
# At minibatch 45800, batch loss 0.004348, batch error rate 0.000000%
# At minibatch 45900, batch loss 0.006894, batch error rate 0.000000%
# At minibatch 46000, batch loss 0.009018, batch error rate 0.000000%
# After epoch 92: valid_err_rate: 0.019500% currently going ot do 128 epochs
# At minibatch 46100, batch loss 0.007155, batch error rate 0.000000%
# At minibatch 46200, batch loss 0.005400, batch error rate 0.000000%
# At minibatch 46300, batch loss 0.009306, batch error rate 0.000000%
# At minibatch 46400, batch loss 0.004619, batch error rate 0.000000%
# At minibatch 46500, batch loss 0.001344, batch error rate 0.000000%
# After epoch 93: valid_err_rate: 0.018700% currently going ot do 128 epochs
# At minibatch 46600, batch loss 0.011118, batch error rate 0.000000%
# At minibatch 46700, batch loss 0.010318, batch error rate 0.000000%
# At minibatch 46800, batch loss 0.007446, batch error rate 0.000000%
# At minibatch 46900, batch loss 0.005924, batch error rate 0.000000%
# At minibatch 47000, batch loss 0.005997, batch error rate 0.000000%
# After epoch 94: valid_err_rate: 0.019400% currently going ot do 128 epochs
# At minibatch 47100, batch loss 0.003946, batch error rate 0.000000%
# At minibatch 47200, batch loss 0.003324, batch error rate 0.000000%
# At minibatch 47300, batch loss 0.007521, batch error rate 0.000000%
# At minibatch 47400, batch loss 0.006414, batch error rate 0.000000%
# At minibatch 47500, batch loss 0.004319, batch error rate 0.000000%
# After epoch 95: valid_err_rate: 0.019200% currently going ot do 128 epochs
# At minibatch 47600, batch loss 0.007727, batch error rate 0.000000%
# At minibatch 47700, batch loss 0.002130, batch error rate 0.000000%
# At minibatch 47800, batch loss 0.006033, batch error rate 0.000000%
# At minibatch 47900, batch loss 0.006256, batch error rate 0.000000%
# At minibatch 48000, batch loss 0.011618, batch error rate 0.000000%
# After epoch 96: valid_err_rate: 0.018800% currently going ot do 128 epochs
# At minibatch 48100, batch loss 0.002782, batch error rate 0.000000%
# At minibatch 48200, batch loss 0.007667, batch error rate 0.000000%
# At minibatch 48300, batch loss 0.011822, batch error rate 1.000000%
# At minibatch 48400, batch loss 0.006258, batch error rate 0.000000%
# At minibatch 48500, batch loss 0.002100, batch error rate 0.000000%
# After epoch 97: valid_err_rate: 0.019700% currently going ot do 128 epochs
# At minibatch 48600, batch loss 0.005750, batch error rate 0.000000%
# At minibatch 48700, batch loss 0.004038, batch error rate 0.000000%
# At minibatch 48800, batch loss 0.005398, batch error rate 0.000000%
# At minibatch 48900, batch loss 0.007067, batch error rate 0.000000%
# At minibatch 49000, batch loss 0.006824, batch error rate 0.000000%
# After epoch 98: valid_err_rate: 0.019000% currently going ot do 128 epochs
# At minibatch 49100, batch loss 0.011213, batch error rate 0.000000%
# At minibatch 49200, batch loss 0.004120, batch error rate 0.000000%
# At minibatch 49300, batch loss 0.008308, batch error rate 0.000000%
# At minibatch 49400, batch loss 0.003304, batch error rate 0.000000%
# At minibatch 49500, batch loss 0.002773, batch error rate 0.000000%
# After epoch 99: valid_err_rate: 0.019500% currently going ot do 128 epochs
# At minibatch 49600, batch loss 0.002989, batch error rate 0.000000%
# At minibatch 49700, batch loss 0.008740, batch error rate 0.000000%
# At minibatch 49800, batch loss 0.006581, batch error rate 0.000000%
# At minibatch 49900, batch loss 0.006994, batch error rate 0.000000%
# At minibatch 50000, batch loss 0.004748, batch error rate 0.000000%
# After epoch 100: valid_err_rate: 0.019000% currently going ot do 128 epochs
# At minibatch 50100, batch loss 0.003432, batch error rate 0.000000%
# At minibatch 50200, batch loss 0.002978, batch error rate 0.000000%
# At minibatch 50300, batch loss 0.002674, batch error rate 0.000000%
# At minibatch 50400, batch loss 0.013430, batch error rate 0.000000%
# At minibatch 50500, batch loss 0.007437, batch error rate 0.000000%
# After epoch 101: valid_err_rate: 0.019100% currently going ot do 128 epochs
# At minibatch 50600, batch loss 0.012041, batch error rate 0.000000%
# At minibatch 50700, batch loss 0.005458, batch error rate 0.000000%
# At minibatch 50800, batch loss 0.008192, batch error rate 0.000000%
# At minibatch 50900, batch loss 0.008810, batch error rate 0.000000%
# At minibatch 51000, batch loss 0.018270, batch error rate 0.000000%
# After epoch 102: valid_err_rate: 0.018800% currently going ot do 128 epochs
# At minibatch 51100, batch loss 0.002680, batch error rate 0.000000%
# At minibatch 51200, batch loss 0.007594, batch error rate 0.000000%
# At minibatch 51300, batch loss 0.010733, batch error rate 0.000000%
# At minibatch 51400, batch loss 0.004532, batch error rate 0.000000%
# At minibatch 51500, batch loss 0.006052, batch error rate 0.000000%
# After epoch 103: valid_err_rate: 0.018700% currently going ot do 128 epochs
# At minibatch 51600, batch loss 0.004412, batch error rate 0.000000%
# At minibatch 51700, batch loss 0.003933, batch error rate 0.000000%
# At minibatch 51800, batch loss 0.004053, batch error rate 0.000000%
# At minibatch 51900, batch loss 0.002533, batch error rate 0.000000%
# At minibatch 52000, batch loss 0.006136, batch error rate 0.000000%
# After epoch 104: valid_err_rate: 0.019400% currently going ot do 128 epochs
# At minibatch 52100, batch loss 0.004016, batch error rate 0.000000%
# At minibatch 52200, batch loss 0.010207, batch error rate 0.000000%
# At minibatch 52300, batch loss 0.011315, batch error rate 1.000000%
# At minibatch 52400, batch loss 0.003167, batch error rate 0.000000%
# At minibatch 52500, batch loss 0.009015, batch error rate 0.000000%
# After epoch 105: valid_err_rate: 0.018600% currently going ot do 128 epochs
# At minibatch 52600, batch loss 0.007545, batch error rate 0.000000%
# At minibatch 52700, batch loss 0.006509, batch error rate 0.000000%
# At minibatch 52800, batch loss 0.002313, batch error rate 0.000000%
# At minibatch 52900, batch loss 0.005072, batch error rate 0.000000%
# At minibatch 53000, batch loss 0.005427, batch error rate 0.000000%
# After epoch 106: valid_err_rate: 0.019200% currently going ot do 128 epochs
# At minibatch 53100, batch loss 0.004843, batch error rate 0.000000%
# At minibatch 53200, batch loss 0.010153, batch error rate 1.000000%
# At minibatch 53300, batch loss 0.007012, batch error rate 0.000000%
# At minibatch 53400, batch loss 0.007489, batch error rate 0.000000%
# At minibatch 53500, batch loss 0.003952, batch error rate 0.000000%
# After epoch 107: valid_err_rate: 0.019000% currently going ot do 128 epochs
# At minibatch 53600, batch loss 0.005636, batch error rate 0.000000%
# At minibatch 53700, batch loss 0.009887, batch error rate 0.000000%
# At minibatch 53800, batch loss 0.005422, batch error rate 0.000000%
# At minibatch 53900, batch loss 0.004501, batch error rate 0.000000%
# At minibatch 54000, batch loss 0.007988, batch error rate 0.000000%
# After epoch 108: valid_err_rate: 0.019200% currently going ot do 128 epochs
# At minibatch 54100, batch loss 0.007294, batch error rate 0.000000%
# At minibatch 54200, batch loss 0.013370, batch error rate 0.000000%
# At minibatch 54300, batch loss 0.002894, batch error rate 0.000000%
# At minibatch 54400, batch loss 0.008674, batch error rate 0.000000%
# At minibatch 54500, batch loss 0.002836, batch error rate 0.000000%
# After epoch 109: valid_err_rate: 0.018600% currently going ot do 128 epochs
# At minibatch 54600, batch loss 0.003715, batch error rate 0.000000%
# At minibatch 54700, batch loss 0.007456, batch error rate 0.000000%
# At minibatch 54800, batch loss 0.007775, batch error rate 0.000000%
# At minibatch 54900, batch loss 0.004430, batch error rate 0.000000%
# At minibatch 55000, batch loss 0.009667, batch error rate 0.000000%
# After epoch 110: valid_err_rate: 0.019000% currently going ot do 128 epochs
# At minibatch 55100, batch loss 0.007757, batch error rate 0.000000%
# At minibatch 55200, batch loss 0.005268, batch error rate 0.000000%
# At minibatch 55300, batch loss 0.003459, batch error rate 0.000000%
# At minibatch 55400, batch loss 0.007976, batch error rate 0.000000%
# At minibatch 55500, batch loss 0.016274, batch error rate 0.000000%
# After epoch 111: valid_err_rate: 0.019000% currently going ot do 128 epochs
# At minibatch 55600, batch loss 0.006745, batch error rate 0.000000%
# At minibatch 55700, batch loss 0.008967, batch error rate 0.000000%
# At minibatch 55800, batch loss 0.006072, batch error rate 0.000000%
# At minibatch 55900, batch loss 0.007380, batch error rate 0.000000%
# At minibatch 56000, batch loss 0.005012, batch error rate 0.000000%
# After epoch 112: valid_err_rate: 0.019200% currently going ot do 128 epochs
# At minibatch 56100, batch loss 0.008683, batch error rate 0.000000%
# At minibatch 56200, batch loss 0.003305, batch error rate 0.000000%
# At minibatch 56300, batch loss 0.002416, batch error rate 0.000000%
# At minibatch 56400, batch loss 0.003021, batch error rate 0.000000%
# At minibatch 56500, batch loss 0.002434, batch error rate 0.000000%
# After epoch 113: valid_err_rate: 0.018700% currently going ot do 128 epochs
# At minibatch 56600, batch loss 0.005303, batch error rate 0.000000%
# At minibatch 56700, batch loss 0.002898, batch error rate 0.000000%
# At minibatch 56800, batch loss 0.006081, batch error rate 0.000000%
# At minibatch 56900, batch loss 0.010978, batch error rate 0.000000%
# At minibatch 57000, batch loss 0.001826, batch error rate 0.000000%
# After epoch 114: valid_err_rate: 0.018300% currently going ot do 172 epochs
# At minibatch 57100, batch loss 0.003539, batch error rate 0.000000%
# At minibatch 57200, batch loss 0.003434, batch error rate 0.000000%
# At minibatch 57300, batch loss 0.002528, batch error rate 0.000000%
# At minibatch 57400, batch loss 0.012699, batch error rate 0.000000%
# At minibatch 57500, batch loss 0.006234, batch error rate 0.000000%
# After epoch 115: valid_err_rate: 0.019200% currently going ot do 172 epochs
# At minibatch 57600, batch loss 0.003763, batch error rate 0.000000%
# At minibatch 57700, batch loss 0.003672, batch error rate 0.000000%
# At minibatch 57800, batch loss 0.007504, batch error rate 0.000000%
# At minibatch 57900, batch loss 0.003689, batch error rate 0.000000%
# At minibatch 58000, batch loss 0.002873, batch error rate 0.000000%
# After epoch 116: valid_err_rate: 0.018900% currently going ot do 172 epochs
# ...
# At minibatch 110700, batch loss 0.003487, batch error rate 0.000000%
# At minibatch 110800, batch loss 0.002785, batch error rate 0.000000%
# At minibatch 110900, batch loss 0.002580, batch error rate 0.000000%
# At minibatch 111000, batch loss 0.004104, batch error rate 0.000000%
# After epoch 222: valid_err_rate: 0.018800% currently going ot do 259 epochs
# At minibatch 111100, batch loss 0.003284, batch error rate 0.000000%
# At minibatch 111200, batch loss 0.004094, batch error rate 0.000000%
# At minibatch 111300, batch loss 0.005203, batch error rate 0.000000%
# At minibatch 111400, batch loss 0.003704, batch error rate 0.000000%
# At minibatch 111500, batch loss 0.002458, batch error rate 0.000000%
# After epoch 223: valid_err_rate: 0.018800% currently going ot do 259 epochs
# At minibatch 111600, batch loss 0.004076, batch error rate 0.000000%
# At minibatch 111700, batch loss 0.001527, batch error rate 0.000000%
# At minibatch 111800, batch loss 0.002904, batch error rate 0.000000%
# At minibatch 111900, batch loss 0.002092, batch error rate 0.000000%
# At minibatch 112000, batch loss 0.004748, batch error rate 0.000000%
# After epoch 224: valid_err_rate: 0.018800% currently going ot do 259 epochs
# At minibatch 112100, batch loss 0.002881, batch error rate 0.000000%
# At minibatch 112200, batch loss 0.002744, batch error rate 0.000000%
# At minibatch 112300, batch loss 0.004605, batch error rate 0.000000%
# At minibatch 112400, batch loss 0.004491, batch error rate 0.000000%
# At minibatch 112500, batch loss 0.007644, batch error rate 0.000000%
# After epoch 225: valid_err_rate: 0.018900% currently going ot do 259 epochs
# At minibatch 112600, batch loss 0.007722, batch error rate 0.000000%
# At minibatch 112700, batch loss 0.006181, batch error rate 0.000000%
# At minibatch 112800, batch loss 0.001967, batch error rate 0.000000%
# At minibatch 112900, batch loss 0.001367, batch error rate 0.000000%
# At minibatch 113000, batch loss 0.004994, batch error rate 0.000000%
# After epoch 226: valid_err_rate: 0.018600% currently going ot do 259 epochs
# At minibatch 113100, batch loss 0.004445, batch error rate 0.000000%
# At minibatch 113200, batch loss 0.003853, batch error rate 0.000000%
# At minibatch 113300, batch loss 0.005853, batch error rate 0.000000%
# At minibatch 113400, batch loss 0.002451, batch error rate 0.000000%
# At minibatch 113500, batch loss 0.002000, batch error rate 0.000000%
# After epoch 227: valid_err_rate: 0.018500% currently going ot do 259 epochs
# At minibatch 113600, batch loss 0.003946, batch error rate 0.000000%
# At minibatch 113700, batch loss 0.004761, batch error rate 0.000000%
# At minibatch 113800, batch loss 0.004622, batch error rate 0.000000%
# At minibatch 113900, batch loss 0.005257, batch error rate 0.000000%
# At minibatch 114000, batch loss 0.005511, batch error rate 0.000000%
# After epoch 228: valid_err_rate: 0.018700% currently going ot do 259 epochs
# At minibatch 114100, batch loss 0.004579, batch error rate 0.000000%
# At minibatch 114200, batch loss 0.002585, batch error rate 0.000000%
# At minibatch 114300, batch loss 0.003356, batch error rate 0.000000%
# At minibatch 114400, batch loss 0.003884, batch error rate 0.000000%
# At minibatch 114500, batch loss 0.005676, batch error rate 0.000000%
# After epoch 229: valid_err_rate: 0.018700% currently going ot do 259 epochs
# At minibatch 114600, batch loss 0.005204, batch error rate 0.000000%
# At minibatch 114700, batch loss 0.003398, batch error rate 0.000000%
# At minibatch 114800, batch loss 0.002122, batch error rate 0.000000%
# At minibatch 114900, batch loss 0.003969, batch error rate 0.000000%
# At minibatch 115000, batch loss 0.002375, batch error rate 0.000000%
# After epoch 230: valid_err_rate: 0.018800% currently going ot do 259 epochs
# At minibatch 115100, batch loss 0.003813, batch error rate 0.000000%
# At minibatch 115200, batch loss 0.006021, batch error rate 0.000000%
# At minibatch 115300, batch loss 0.002891, batch error rate 0.000000%
# At minibatch 115400, batch loss 0.004954, batch error rate 0.000000%
# At minibatch 115500, batch loss 0.002564, batch error rate 0.000000%
# After epoch 231: valid_err_rate: 0.018500% currently going ot do 259 epochs
# At minibatch 115600, batch loss 0.003395, batch error rate 0.000000%
# At minibatch 115700, batch loss 0.005908, batch error rate 0.000000%
# At minibatch 115800, batch loss 0.003768, batch error rate 0.000000%
# At minibatch 115900, batch loss 0.002536, batch error rate 0.000000%
# At minibatch 116000, batch loss 0.007305, batch error rate 0.000000%
# After epoch 232: valid_err_rate: 0.018900% currently going ot do 259 epochs
# At minibatch 116100, batch loss 0.002434, batch error rate 0.000000%
# At minibatch 116200, batch loss 0.006852, batch error rate 0.000000%
# At minibatch 116300, batch loss 0.008185, batch error rate 0.000000%
# At minibatch 116400, batch loss 0.008510, batch error rate 0.000000%
# At minibatch 116500, batch loss 0.003946, batch error rate 0.000000%
# After epoch 233: valid_err_rate: 0.018600% currently going ot do 259 epochs
# At minibatch 116600, batch loss 0.002320, batch error rate 0.000000%
# At minibatch 116700, batch loss 0.002556, batch error rate 0.000000%
# At minibatch 116800, batch loss 0.002836, batch error rate 0.000000%
# At minibatch 116900, batch loss 0.002571, batch error rate 0.000000%
# At minibatch 117000, batch loss 0.002868, batch error rate 0.000000%
# After epoch 234: valid_err_rate: 0.018600% currently going ot do 259 epochs
# At minibatch 117100, batch loss 0.003971, batch error rate 0.000000%
# At minibatch 117200, batch loss 0.004440, batch error rate 0.000000%
# At minibatch 117300, batch loss 0.004642, batch error rate 0.000000%
# At minibatch 117400, batch loss 0.006662, batch error rate 0.000000%
# At minibatch 117500, batch loss 0.005029, batch error rate 0.000000%
# After epoch 235: valid_err_rate: 0.018800% currently going ot do 259 epochs
# At minibatch 117600, batch loss 0.001650, batch error rate 0.000000%
# At minibatch 117700, batch loss 0.005843, batch error rate 0.000000%
# At minibatch 117800, batch loss 0.004687, batch error rate 0.000000%
# At minibatch 117900, batch loss 0.004508, batch error rate 0.000000%
# At minibatch 118000, batch loss 0.004232, batch error rate 0.000000%
# After epoch 236: valid_err_rate: 0.018500% currently going ot do 259 epochs
# At minibatch 118100, batch loss 0.002271, batch error rate 0.000000%
# At minibatch 118200, batch loss 0.006497, batch error rate 0.000000%
# At minibatch 118300, batch loss 0.002843, batch error rate 0.000000%
# At minibatch 118400, batch loss 0.002494, batch error rate 0.000000%
# At minibatch 118500, batch loss 0.003117, batch error rate 0.000000%
# After epoch 237: valid_err_rate: 0.018200% currently going ot do 259 epochs
# At minibatch 118600, batch loss 0.002265, batch error rate 0.000000%
# At minibatch 118700, batch loss 0.004309, batch error rate 0.000000%
# At minibatch 118800, batch loss 0.002993, batch error rate 0.000000%
# At minibatch 118900, batch loss 0.002520, batch error rate 0.000000%
# At minibatch 119000, batch loss 0.005478, batch error rate 0.000000%
# After epoch 238: valid_err_rate: 0.018600% currently going ot do 259 epochs
# At minibatch 119100, batch loss 0.002918, batch error rate 0.000000%
# At minibatch 119200, batch loss 0.004806, batch error rate 0.000000%
# At minibatch 119300, batch loss 0.003491, batch error rate 0.000000%
# At minibatch 119400, batch loss 0.004916, batch error rate 0.000000%
# At minibatch 119500, batch loss 0.006028, batch error rate 0.000000%
# After epoch 239: valid_err_rate: 0.018500% currently going ot do 259 epochs
# At minibatch 119600, batch loss 0.002397, batch error rate 0.000000%
# At minibatch 119700, batch loss 0.002663, batch error rate 0.000000%
# At minibatch 119800, batch loss 0.002517, batch error rate 0.000000%
# At minibatch 119900, batch loss 0.005123, batch error rate 0.000000%
# At minibatch 120000, batch loss 0.003615, batch error rate 0.000000%
# After epoch 240: valid_err_rate: 0.018400% currently going ot do 259 epochs
# At minibatch 120100, batch loss 0.002934, batch error rate 0.000000%
# At minibatch 120200, batch loss 0.006767, batch error rate 0.000000%
# At minibatch 120300, batch loss 0.002900, batch error rate 0.000000%
# At minibatch 120400, batch loss 0.004296, batch error rate 0.000000%
# At minibatch 120500, batch loss 0.005926, batch error rate 0.000000%
# After epoch 241: valid_err_rate: 0.018800% currently going ot do 259 epochs
# At minibatch 120600, batch loss 0.008725, batch error rate 0.000000%
# At minibatch 120700, batch loss 0.002005, batch error rate 0.000000%
# At minibatch 120800, batch loss 0.003945, batch error rate 0.000000%
# At minibatch 120900, batch loss 0.001580, batch error rate 0.000000%
# At minibatch 121000, batch loss 0.004264, batch error rate 0.000000%
# After epoch 242: valid_err_rate: 0.018700% currently going ot do 259 epochs
# At minibatch 121100, batch loss 0.004076, batch error rate 0.000000%
# At minibatch 121200, batch loss 0.003394, batch error rate 0.000000%
# At minibatch 121300, batch loss 0.002104, batch error rate 0.000000%
# At minibatch 121400, batch loss 0.002059, batch error rate 0.000000%
# At minibatch 121500, batch loss 0.003789, batch error rate 0.000000%
# After epoch 243: valid_err_rate: 0.018600% currently going ot do 259 epochs
# At minibatch 121600, batch loss 0.004984, batch error rate 0.000000%
# At minibatch 121700, batch loss 0.004681, batch error rate 0.000000%
# At minibatch 121800, batch loss 0.004327, batch error rate 0.000000%
# At minibatch 121900, batch loss 0.001353, batch error rate 0.000000%
# At minibatch 122000, batch loss 0.001476, batch error rate 0.000000%
# After epoch 244: valid_err_rate: 0.018800% currently going ot do 259 epochs
# At minibatch 122100, batch loss 0.003786, batch error rate 0.000000%
# At minibatch 122200, batch loss 0.002369, batch error rate 0.000000%
# At minibatch 122300, batch loss 0.004113, batch error rate 0.000000%
# At minibatch 122400, batch loss 0.003060, batch error rate 0.000000%
# At minibatch 122500, batch loss 0.003640, batch error rate 0.000000%
# After epoch 245: valid_err_rate: 0.018500% currently going ot do 259 epochs
# At minibatch 122600, batch loss 0.006950, batch error rate 0.000000%
# At minibatch 122700, batch loss 0.003945, batch error rate 0.000000%
# At minibatch 122800, batch loss 0.004054, batch error rate 0.000000%
# At minibatch 122900, batch loss 0.003105, batch error rate 0.000000%
# At minibatch 123000, batch loss 0.002494, batch error rate 0.000000%
# After epoch 246: valid_err_rate: 0.018800% currently going ot do 259 epochs
# At minibatch 123100, batch loss 0.003936, batch error rate 0.000000%
# At minibatch 123200, batch loss 0.003164, batch error rate 0.000000%
# At minibatch 123300, batch loss 0.005904, batch error rate 0.000000%
# At minibatch 123400, batch loss 0.003721, batch error rate 0.000000%
# At minibatch 123500, batch loss 0.002095, batch error rate 0.000000%
# After epoch 247: valid_err_rate: 0.018400% currently going ot do 259 epochs
# At minibatch 123600, batch loss 0.002008, batch error rate 0.000000%
# At minibatch 123700, batch loss 0.007100, batch error rate 0.000000%
# At minibatch 123800, batch loss 0.007126, batch error rate 0.000000%
# At minibatch 123900, batch loss 0.005005, batch error rate 0.000000%
# At minibatch 124000, batch loss 0.003192, batch error rate 0.000000%
# After epoch 248: valid_err_rate: 0.018700% currently going ot do 259 epochs
# At minibatch 124100, batch loss 0.005784, batch error rate 0.000000%
# At minibatch 124200, batch loss 0.003205, batch error rate 0.000000%
# At minibatch 124300, batch loss 0.003075, batch error rate 0.000000%
# At minibatch 124400, batch loss 0.004824, batch error rate 0.000000%
# At minibatch 124500, batch loss 0.001434, batch error rate 0.000000%
# After epoch 249: valid_err_rate: 0.018700% currently going ot do 259 epochs
# At minibatch 124600, batch loss 0.003974, batch error rate 0.000000%
# At minibatch 124700, batch loss 0.004059, batch error rate 0.000000%
# At minibatch 124800, batch loss 0.003645, batch error rate 0.000000%
# At minibatch 124900, batch loss 0.004370, batch error rate 0.000000%
# At minibatch 125000, batch loss 0.003338, batch error rate 0.000000%
# After epoch 250: valid_err_rate: 0.018400% currently going ot do 259 epochs
# At minibatch 125100, batch loss 0.002017, batch error rate 0.000000%
# At minibatch 125200, batch loss 0.004833, batch error rate 0.000000%
# At minibatch 125300, batch loss 0.004769, batch error rate 0.000000%
# At minibatch 125400, batch loss 0.002247, batch error rate 0.000000%
# At minibatch 125500, batch loss 0.007235, batch error rate 0.000000%
# After epoch 251: valid_err_rate: 0.018600% currently going ot do 259 epochs
# At minibatch 125600, batch loss 0.001874, batch error rate 0.000000%
# At minibatch 125700, batch loss 0.004436, batch error rate 0.000000%
# At minibatch 125800, batch loss 0.004380, batch error rate 0.000000%
# At minibatch 125900, batch loss 0.004807, batch error rate 0.000000%
# At minibatch 126000, batch loss 0.004674, batch error rate 0.000000%
# After epoch 252: valid_err_rate: 0.018500% currently going ot do 259 epochs
# At minibatch 126100, batch loss 0.002910, batch error rate 0.000000%
# At minibatch 126200, batch loss 0.003314, batch error rate 0.000000%
# At minibatch 126300, batch loss 0.003877, batch error rate 0.000000%
# At minibatch 126400, batch loss 0.003424, batch error rate 0.000000%
# At minibatch 126500, batch loss 0.003901, batch error rate 0.000000%
# After epoch 253: valid_err_rate: 0.018600% currently going ot do 259 epochs
# At minibatch 126600, batch loss 0.001504, batch error rate 0.000000%
# At minibatch 126700, batch loss 0.005450, batch error rate 0.000000%
# At minibatch 126800, batch loss 0.007879, batch error rate 0.000000%
# At minibatch 126900, batch loss 0.004380, batch error rate 0.000000%
# At minibatch 127000, batch loss 0.002803, batch error rate 0.000000%
# After epoch 254: valid_err_rate: 0.018600% currently going ot do 259 epochs
# At minibatch 127100, batch loss 0.001453, batch error rate 0.000000%
# At minibatch 127200, batch loss 0.003070, batch error rate 0.000000%
# At minibatch 127300, batch loss 0.002409, batch error rate 0.000000%
# At minibatch 127400, batch loss 0.003358, batch error rate 0.000000%
# At minibatch 127500, batch loss 0.007586, batch error rate 0.000000%
# After epoch 255: valid_err_rate: 0.018800% currently going ot do 259 epochs
# At minibatch 127600, batch loss 0.004413, batch error rate 0.000000%
# At minibatch 127700, batch loss 0.003725, batch error rate 0.000000%
# At minibatch 127800, batch loss 0.003312, batch error rate 0.000000%
# At minibatch 127900, batch loss 0.003250, batch error rate 0.000000%
# At minibatch 128000, batch loss 0.004184, batch error rate 0.000000%
# After epoch 256: valid_err_rate: 0.018500% currently going ot do 259 epochs
# At minibatch 128100, batch loss 0.001764, batch error rate 0.000000%
# At minibatch 128200, batch loss 0.003688, batch error rate 0.000000%
# At minibatch 128300, batch loss 0.002312, batch error rate 0.000000%
# At minibatch 128400, batch loss 0.003680, batch error rate 0.000000%
# At minibatch 128500, batch loss 0.001881, batch error rate 0.000000%
# After epoch 257: valid_err_rate: 0.018700% currently going ot do 259 epochs
# At minibatch 128600, batch loss 0.006415, batch error rate 0.000000%
# At minibatch 128700, batch loss 0.003825, batch error rate 0.000000%
# At minibatch 128800, batch loss 0.004550, batch error rate 0.000000%
# At minibatch 128900, batch loss 0.005046, batch error rate 0.000000%
# At minibatch 129000, batch loss 0.002792, batch error rate 0.000000%
# After epoch 258: valid_err_rate: 0.018300% currently going ot do 259 epochs
# At minibatch 129100, batch loss 0.001474, batch error rate 0.000000%
# At minibatch 129200, batch loss 0.002743, batch error rate 0.000000%
# At minibatch 129300, batch loss 0.003016, batch error rate 0.000000%
# At minibatch 129400, batch loss 0.004749, batch error rate 0.000000%
# At minibatch 129500, batch loss 0.003498, batch error rate 0.000000%
# After epoch 259: valid_err_rate: 0.018600% currently going ot do 259 epochs
# Test error rate: 0.018800

# %%
compute_error_rate(net, mnist_test_stream)
# Out:
# 0.0188

# %% [markdown]
# # Problem 3 [2p bonus]
#
# Implement norm constraints, i.e. limit the total
# norm of connections incoming to a neuron. In our case, this
# corresponds to clipping the norm of *rows* of weight
# matrices. An easy way of implementing it is to make a gradient
# step, then look at the norm of rows and scale down those that are
# over the threshold (this technique is called "projected gradient descent").

# %% [markdown]
# # Problem 4 [2p bonus]
#
# Implement a **dropout** layer and try to train a
# network getting below 1.5% test error rates with dropout (the best
# result is below 1\% for dropout!). Details: http://arxiv.org/pdf/1207.0580.pdf.

# %% [markdown]
# # Problem 5 [3p bonus]
#
# Implement convolutional and max-pooling layers and (without dropout) get a test error rate below 1.5%.

# %% [markdown]
# # Problem 6 [1-3p bonus]
#
# Implement a data augmentation method (e.g. rotations, noise, crops) that will yield a significant test error rate reduction for your network. Number of bonus points depends on the ingenuity of your solution and error rate gains.
