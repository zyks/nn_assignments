# %% [markdown]
# # Assignment 1
#
# **Submission deadline:**
# * **Problems 1-4: last lab session before or on Thursday, 9.3.17**
# * **Problems 5-6: last lab session before or on Thursday, 16.3.17**
#
# **Points: 10 + 4 bonus points**
#
# Please note: some of the assignments are tedious or boring if you are already a NumPy ninja. The bonus problems were designed to give you a more satisfying alternative.
#
# ## Downloading this notebook
#
# This assignment is an Jupyter notebook. Download it by cloning https://github.com/janchorowski/nn_assignments. Follow the instructions in its README for instructions. Whenever possible, add your solutions to the notebook.
#
# Please email us about any problems with it - we will try to correct them quickly. Also, please do not hesitate to use GitHub’s pull requests to send us corrections!

# %%
# Standard IPython notebook imports
# %matplotlib inline

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

# %% [markdown]
# ## Problem 0 [0p]
#
# Get familiar with our [lab guide](https://docs.google.com/viewer?a=v&pid=sites&srcid=Y3MudW5pLndyb2MucGx8amNofGd4OjM0ZTU2MjA4M2NlOGIwNmE). It is not obligatory to use the labs remotely and most of the time you will do just fine with your own machine. However, we recommend using labs for the most computationally-intensive tasks such as the final projects.
#
# Make sure you know how to:
# * load up-to-date Anaconda Python distribution with `/pio/os/anaconda/set-env.sh` (confirm with `python -V`)
# <br/>
# (also: look into this `nn_assignments`' `set-env.sh` and see that it loads `Anaconda` for you),
# * connect to labs 110/137 from *outside* of the faculty,
# * copy a file over an ssh tunnel or connect remotely to a Jupyter Notebook,
# * use `GNU screen` and/or `nohup`,
# * leave a process running, disconnect, connect again and verify it is still running.
#
# In case of problems, ask for help!

# %% [markdown]
# ## Problem 1 [2p]
#
# First, get familiar with Python at https://docs.python.org/2/tutorial/. Then, get
# to know the capabilities of NumPy, the prime numerical library of Python http://www.numpy.org/, for instance with the tutorial at http://wiki.scipy.org/Tentative_NumPy_Tutorial.
#
# You might also need:
#   1. another intro to NumPy,
# http://people.duke.edu/~ccc14/pcfb/numerics.html
#   2. a better interactive shell for Python,
# http://ipython.org/
#   3. access to IPython through an ordinary web browser,
# http://ipython.org/notebook.html
#   4. a plotting library for Python.
# http://matplotlib.org/
#
# **a) Declare variables:**
# 1. $a=10$,
# 2. $b=2.5\times 10^{23}$,
# 3. $c=2+3i$, where $i$ is an imaginary unit,
# 4. $d=e^{i2\pi/3}$, where $i$ is an imaginary unit, $e$ is the Euler's number (use `exp`, `pi`).

# %%
# TODO: Complete the declarations
from cmath import exp, pi

a = 10
b = 2.5 * 10 ** 23
c = 2 + 3j
d = exp(2j*pi/3)

# %% [markdown]
# **b) Declare vectors:**
# 1. $aVec=\begin{bmatrix} 3.14 & 15 & 9 & 26 \end{bmatrix}$,
# 2. $bVec=\begin{bmatrix} 2.71 & 8 & 28 & 182 \end{bmatrix}^\intercal$ (column vector),
# 3. $cVec=\begin{bmatrix} 5 & 4.8 & \cdots & -4.8 & -5 \end{bmatrix}$ (vector of numbers from $5$ to $-5$ decreasing by $0.2$),
# 4. $dVec=\begin{bmatrix} 10^0 & 10^{0.01} & \cdots & 10^{0.99} & 10^1 \end{bmatrix}$ (logarithmically spaced numbers from 1 to 10, use `logspace` and make sure, that the result has correct length!),
# 5. $eVec=Hello$ ($eVec$ is a string of characters, thus a vector).

# %%
import numpy as np

aVec = np.array([3.14, 15, 9, 26])
bVec = np.array([2.71, 8, 28, 182]).reshape(4, 1)
cVec = np.arange(5, -5.2, -0.2)
dVec = np.logspace(0, 1, 101)
eVec = np.array('Hello', dtype=str)
eVec2 = np.array(list("Hello"))
# Out:
# Vendor:  Continuum Analytics, Inc.
# Package: mkl
# Message: trial mode expires in 30 days

# %%
eVec
# Out:
# array('Hello',
#       dtype='|S5')

# %%
eVec2
# Out:
# array(['H', 'e', 'l', 'l', 'o'],
#       dtype='|S1')

# %% [markdown]
# **c) Declare matrices:**
# 1. $aMat=\begin{bmatrix}
#                     2      & \cdots & 2 \\
#                     \vdots & \ddots & \vdots \\
#                     2      & \cdots & 2
#                 \end{bmatrix}$,
# <br/>
# matrix $9\times 9$ filled with 2s (use `ones` or `zeros`),
# 2. $bMat=\begin{bmatrix}
#                     1      & 0      & \cdots &        & 0      \\
#                     0      & \ddots & 0      &        & 0      \\
#                     \vdots & 0      & 5      & 0      & \vdots \\
#                            &        & 0      & \ddots & 0      \\
#                     0      &        & \cdots & 0      & 1
#                 \end{bmatrix}$,
# <br/>
# matrix $9\times 9$ filled with zeros, with $\begin{bmatrix} 1 & 2 & 3 & 4 & 5 & 4 & 3 & 2 & 1 \end{bmatrix}$ on its diagonal (use `zeros`, `diag`),
# 3. $cMat=\begin{bmatrix}
#                     1      & 11     & \cdots & 91     \\
#                     2      & 12     & \ddots & 92     \\
#                     \vdots & \vdots & \ddots & \vdots \\
#                     10     & 20     & \cdots & 100
#                 \end{bmatrix}$,
# <br/>
# matrix $10\times 10$, columns of which form the vector $1:100$ (use `reshape`),
# 4. $dMat=\begin{bmatrix}
#                     NaN & NaN & NaN & NaN \\
#                     NaN & NaN & NaN & NaN \\
#                     NaN & NaN & NaN & NaN
#                 \end{bmatrix}$,
# <br/>
# matrix $3\times 4$ filled with `NaN`s (use... `NaN`),
# 5. $eMat=\begin{bmatrix}
#                     13  & -1  & 5  \\
#                     -22 & 10  & -87
#                 \end{bmatrix}$,
# <br/>
# 6. $fMat$ filled with random natural numbers from $[-3,3]$ (use `rand` and `floor` or `ceil`).

# %%
aMat = np.ones(81).reshape(9, 9) * 2
bMat = np.diag(np.append(np.arange(1,5), np.arange(5,0,-1)))
cMat = np.arange(1, 101).reshape(10, 10).transpose()
dMat = np.array([np.NaN] * 12).reshape(3, 4)
eMat = np.array([[13, -1, 5], [-22, 10, -87]], dtype=int)
fMat = np.ceil(np.random.rand(3,2) * 6 - 3)

# %% [markdown]
# ** d) Declare a multiplication table ** as a $10\times 10$ matrix `mulMat`. Use matrix/vector multiplication.

# %%
mulMat = np.arange(1, 11) * np.arange(1, 11).reshape(10, 1)

# %% [markdown]
# ** e) Compute elemwise using values from b).**
# For instance, the first element of $xVec[0]$ should be equal to
#
# \begin{equation}
# 1/(\sqrt{2\pi2.5^2}) e^{-cVec[0]^2 / (2\cdot\pi 2.5^2)}.
# \end{equation}
#
# 1. $xVec=1/(\sqrt{2\pi2.5^2}) e^{-cVec^2 / (2\cdot\pi 2.5^2)}$
# 2. $yVec=\sqrt{(aVec^\intercal)^2 + bVec^2}$
# 3. $zVec=\log_{10}(1/dVec)$, using `log10`

# %%
xVec = 1. / np.sqrt(2 * np.pi * 2.5 ** 2) * np.exp(-cVec ** 2 / (2 * np.pi * 2.5 ** 2))
yVec = np.sqrt(aVec.T ** 2 + bVec ** 2)
zVec = np.log10(1. / dVec)

# %% [markdown]
# ** f) Compute with matrix/vector operations using values from c).**
# 1. $xMat=(aVec\cdot bVec)aMat^2$,
# 2. $yMat=bVec\cdot aVec$
# <br/>
# (remember, that matrix multiplication is not commutative),
# 4. $zMat=\lvert cMat\rvert (aMat\cdot bMat)^\intercal$, where $\lvert A\rvert$ denotes determinant of $A$ (use `det`).

# %%
xMat = np.dot(aVec.reshape(1,4), bVec)[0][0] * np.dot(aMat, aMat)
yMat = np.dot(bVec, aVec.reshape(1, 4))
zMat = np.linalg.det(cMat) * np.dot(aMat, bMat).T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-80f29f2bc955> in <module>()
# ----> 1 xMat = np.dot(aVec.reshape(1,4), bVec)[0][0] * np.dot(aMat, aMat)
#       2 yMat = np.dot(bVec, aVec.reshape(1, 4))
#       3 zMat = np.linalg.det(cMat) * np.dot(aMat, bMat).T
#
# NameError: name 'aMat' is not defined

# %% [markdown]
# ** g) Declare `ismagic(A)` function ** which checks if matrix $A$ is a [magic square](https://en.wikipedia.org/wiki/Magic_square) and returns a boolean.

# %%
np.concatenate((np.array([1]), np.array([2]), np.array([3])))
# Out:
# array([1, 2, 3])

# %%
def ismagic(A): 
    def has_equal_dimensions(A): 
        return A.shape[0] == A.shape[1]
    
    def column_row_diagonal_sums_are_equal(A):
        magic_constant = A[:, 0].sum()
        sums = np.concatenate((A.sum(axis=0), A.sum(axis=1), np.array([np.trace(A), np.trace(np.fliplr(A))])))
        return np.all(sums == magic_constant)
    
#     def column_row_diagonal_sums_are_equal2(A):
#         magic_constant = A[:, 0].sum()
#         for i in range(A.shape[0]):
#             if A[:, i].sum() != magic_constant or A[i, :].sum() != magic_constant:
#                 return False
#         return np.trace(A) == np.trace(np.fliplr(A)) == magic_constant

    return has_equal_dimensions(A) and column_row_diagonal_sums_are_equal(A)

# %%
A = np.array([[2, 7, 6], [9, 5, 1], [4, 3, 8]])
B = np.array([[1, 2, 3], [4, 5, 6]])
C = np.array([[1, 1], [1, 1]])
D = np.array([[2, 7, 6], [9, 5, 1], [4, 2, 8]])
print ismagic(A)
print ismagic(B)
print ismagic(C)
print ismagic(D)
# Out:
# True
# False
# True
# False

# %%
A.sum(axis=1, keepdims=True)
# Out:
# array([[15],
#        [15],
#        [15]])

# %% [markdown]
# # k-Nearest Neighbors
#
# The following excerpt of code loads the data describing iris flowers
# and shows relations between their length and petal width for three
# species (namely: setosa, versicolor, virginica).

# %%
# pylab - loads numerical and graphical libraries into the IPython notebook
# %pylab inline

# sklearn is a large collection of machine learning algorithms
# here we’ll use it only for the built-in iris dataset
from sklearn import datasets

iris = datasets.load_iris()

print('Features: ', iris.feature_names)
print('Targets: ', iris.target_names)

petal_length = iris.data[:,iris.feature_names.index('petal length (cm)')]
petal_width = iris.data[:, iris.feature_names.index('petal width (cm)')]

for target in set(iris.target):
    example_ids = target==iris.target
    scatter(petal_length[example_ids], petal_width[example_ids],
            label=iris.target_names[target], color='bgr'[target],
            marker='x', alpha=0.7)
unknown = np.array([
                    [1.5, 0.3],
                    [4.5, 1.2],
                    [5.5, 2.3],
                    [5.1, 1.7]
                   ])
scatter(unknown[:,0], unknown[:,1], marker='v', color='gray', s=50, label='??')
xlabel('petal length (cm)')
ylabel('petal width (cm)')
grid(True)
legend(loc='upper left')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# ('Features: ', ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)'])
# ('Targets: ', array(['setosa', 'versicolor', 'virginica'],
#       dtype='|S10'))

# %% [markdown]
# Based on these two features, it is easy to distinguish iris setosa from the two remaining species. Yet iris versicolor and virginica remain mixed together.
#
# Looking closely at the plot, we might estimate the spieces of the selected unknown irises (gray triangles). For three of them the answer seems obvious – they belong in uniformly-colored areas covered by one spieces only. Yet unknown iris flower in (5.1, 1.7) is troublesome – it lays on the boundary of versicolor and virginica clusters. We can assume, that its species is the one of the closest one to it, coming from the training set (and so having a label).
#
# K-Nearest Neighbors method (http://en.wikipedia.org/wiki/K-nearest_neighbors_algorithm) solves the classification problem, i.e. sets class labels (species in case of irises) of a previously unseen sample by choosing the most common class among the top k neighbors of the sample in question (for instance according to the Euclidean distance). Thus, the k-Nearest Neighbors algorithm works as follows. For each unlabeled sample x:
# 1. Find k nearest neighbors among the labeled samples.
# 2. Set the most common label among them as label of x.

# %% [markdown]
# ## Problem 2 [2p]
#
# 1.  **[1p]** Load the iris data (in Python it’s built-in into machine learning libraries, use sklearn.datasets.load_iris), the data is also available on-line at https://archive.ics.uci.edu/ml/datasets/Iris
#
# 2.  **[1p]** Irises are described with 4 attributes: petal and sepal widths and lengths. We often plot such data as matrices depicting relationships between pairs of attributes (the diagonal of which holds an ordinary histogram). Write code making a plot like the one below. Please pay attention to the details: make a proper legend and correctly label the axes.
#
# <img src="iris4x4.png"/>

# %%
# %pylab inline
from sklearn import datasets

iris = datasets.load_iris()
# iris.data.T
attributes = [iris.data[:,iris.feature_names.index(fn)] for fn in iris.feature_names]

fig, ax = subplots(len(attributes), len(attributes), figsize=(10, 10))
leg = [None for _ in range(len(attributes))]

for i in range(len(attributes)):
    for j in range(len(attributes)):
        for target in set(iris.target):
            if i == j:
                ax[i][j].hist(attributes[j], color='b')
            else:
                target_ids = iris.target == target
                leg[target] = ax[i][j].scatter(
                    attributes[j][target_ids], attributes[i][target_ids], 
                    label=iris.target_names[target], color='bgr'[target],
                    alpha=0.7
                )

for i in range(len(attributes)):
    ax[i][0].set_ylabel(iris.feature_names[i])
    ax[len(attributes) - 1][i].set_xlabel(iris.feature_names[i])

fig.legend(leg, labels=iris.target_names, loc='upper center', ncol=3)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['source', 'indices']
# `%matplotlib` prevents importing * from pylab and numpy

# %% [markdown]
# ## Problem 3 [2p]
#
# Implement the k-Nearest Neighbors algorithm. Try to
# take advantage of matrix calculus rather than using for loops.
#
# **Tip:** What is computed by \begin{equation} \sqrt{(X - Y)^T (X - Y)} \end{equation} when both X and Y are vectors?
#
# **Tip:** Try to use broadcasting (NumPy: http://docs.scipy.org/doc/numpy/user/basics.broadcasting.html) and built-ins sort, numpy.sort, numpy.argsort (sorting), scipy.stats.mode (choosing the most common element of the set).

# %%
import numpy as np

def kNN(k, test_point, training_points, labels):
    distances = ((training_points - test_point) ** 2).sum(axis=1)
    k_closest_nbh_indices = distances.argpartition(k)[:k]
    nbh_labels, labels_count = np.unique(labels[k_closest_nbh_indices], return_counts=True)
    return nbh_labels[labels_count.argmax()]

# %% [markdown]
# ## Problem 4 [2p]
# Consider the following experiment:
# 1. We scramble the data and split it into two parts - training set (66.6% of all samples) and test set (33.4%).
# 2. Based on the training set, we use the k-NN algorithm to predict the labels on the test set.
# 3. We then check the number of errors and write it down.
#
# Do this 500 times for k ∈ {1, 3, 5, ..., 19}. Plot a function of the average number of errors
# as the function of k. It should be similar to the one below.
#
# <img src="knn.png"/>

# %%
# %pylab inline
import numpy as np
from sklearn import datasets

def get_training_and_test_sets(data, labels, test_data_len):
    indices = np.arange(data.shape[0])
    np.random.shuffle(indices)    
    test_indices = indices[:test_data_len]
    training_indices = indices[test_data_len:]
    training_set = data[training_indices], labels[training_indices]
    test_set = data[test_indices], labels[test_indices]
    return training_set, test_set

iris_data = datasets.load_iris()
tries = 500
test_data_len = int(iris_data.data.shape[0] * 0.33)
ks = np.arange(1, 20, 2)
failures = np.zeros(10)

for _ in range(tries):
    training_set, test_set = get_training_and_test_sets(iris_data.data, iris_data.target, test_data_len)
    training_data, training_labels = training_set
    test_data, test_labels = test_set
    for k in ks:
        for i in range(test_data_len):
            label = kNN(k, test_data[i], training_data, training_labels)
            if label != test_labels[i]:
                failures[(k-1)/2] += 1

failures = failures * 100 / (test_data_len * 500)
plot(ks, failures, marker='x')
xlabel('K')
ylabel('Average classification error [%]')
title('Iris classification using k-NN')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /pio/lscratch/1/os/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:28: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %% [markdown]
# ## Problem 5 [2p]
#
# Apply the K-Nearest Neighbors (K-NN) algorithm to the MNIST and CIFAR10 datasets.
#
# The MNIST (http://yann.lecun.com/exdb/mnist/) dataset consists of normalized (centered and stretched) scans of hand-written digits. Specifically, each element of the dataset is a 28 × 28 grayscale image, thus having 764 8-bit pixels.
#
# The CIFAR10 (http://www.cs.toronto.edu/~kriz/cifar.html) dataset consists of small, 32 by 32 pixels, RGB images belonging to 10 categories.
#
# 1. **[1p]** Download and load the MNIST and CIFAR10 datasets. For both datasets, display a few objects from each of the classes, paying attention to aesthetics and clarity of your presentation. **Note:** the datasets are available on Lab computers. Please use the code below to get started.
#
# 2. **[2p]** Apply a k-NN classifier to the MNIST and CIFAR10 datasets. First, divide the training set into two parts, which we will call training and validation. On MNIST use the first 50000 samples for training and the last 10000 for validation. On CIFAR10, use 40000 to train and 10000 for validation. Then find the optimal number of neighbors by assessing the accuracy on the validation set. You do not need to repeat this experiment multiple times. Finally, compute the accuracy on the test set obtained with the best previously chosen number of neighbors. On MNIST you should get about 3% errors, while on CIFAR10 you should get about 70% errors. Why CIFAR10 is harder than MNIST? Pick a few mislabeled samples from the test dataset and plot them along with the correct ones.
#
# **Note:**
#   * MNIST and CIFAR10 are much larger than the Iris dataset. A good implementation needs about XXX minutes on Lab computers. Please optimize your algorithm:
#   * Compute the distances only once, then test for different values of k.
#   * Use vectorized expressions to compute the distance. It is possible to compute all distances between the training and testing points in one expression. Hint: think about the vectorized expression \begin{equation}(X - Y)^T (X - Y).\end{equation}
#   * You can use single precision numbers in computation.
#   * If your code is taking a long time o execute, please save its results before the lab session.
#
# **Note:** in NumPy, matrices have its own data type (dtype), which is retained during
# calculations. Please pay attention, i.e. do not subtract values of data types not
# having the sign bit, do not divide integers, etc. Results of such operations won’t be
# automatically casted to types having the required precision.

# %%
# loading MNIST data

import numpy as np
from fuel.datasets.mnist import MNIST
from common.plotting import plot_mat
import matplotlib.pyplot as plt


mnist_train = MNIST(("train",), subset=slice(None,50000))
mnist_validation = MNIST(("train",), subset=slice(50000, None))
mnist_test = MNIST(("test",))

print("We have %d training, %d validation, and %d test examples" % (
    mnist_train.num_examples, mnist_validation.num_examples, mnist_test.num_examples))
print("The examples are pairs of %s:" % (mnist_train.sources,))
for i, source in enumerate(mnist_train.sources):
    labels = mnist_train.axis_labels[source]
    print('The source #%d named "%s" is a %dd array with axis: %s' % (
        i, source, len(labels), labels))

#Note that for larger datasets that are loaded into mameory the data_sources field may not exist!
# plot_mat(mnist_train.data_sources[0][:20], cmap='gray')
# Out:
# We have 50000 training, 10000 validation, and 10000 test examples
# The examples are pairs of (u'features', u'targets'):
# The source #0 named "features" is a 4d array with axis: (u'batch', u'channel', u'height', u'width')
# The source #1 named "targets" is a 2d array with axis: (u'batch', u'index')

# %%
# loading CIFAR10 data

from fuel.datasets.cifar10 import CIFAR10


cifar10_train = CIFAR10(("train",), subset=slice(None,40000))
cifar10_validation = CIFAR10(("train",), subset=slice(40000, None))
cifar10_test = CIFAR10(("test",))

print("We have %d training, %d validation, and %d test examples" % (
    cifar10_train.num_examples, cifar10_validation.num_examples, cifar10_test.num_examples))
print("The examples are pairs of %s:" % (cifar10_train.sources,))
for i, source in enumerate(cifar10_train.sources):
    labels = cifar10_train.axis_labels[source]
    print('The source #%d named "%s" is a %dd array with axis: %s' % (
        i, source, len(labels), labels))

# plot_mat(cifar10_train.data_sources[0][:20])
# Out:
# We have 40000 training, 10000 validation, and 10000 test examples
# The examples are pairs of (u'features', u'targets'):
# The source #0 named "features" is a 4d array with axis: (u'batch', u'channel', u'height', u'width')
# The source #1 named "targets" is a 2d array with axis: (u'batch', u'index')

# %%
#
# TODO: plot an example of each class on MNIST and on CIFAR
#

# %%
# MNIST
_, indices = np.unique(mnist_train.data_sources[1], return_index=True)
plot_mat(mnist_train.data_sources[0][indices], cmap='gray')

# %%
# CIFAR
_, indices = np.unique(cifar10_train.data_sources[1], return_index=True)
plot_mat(cifar10_train.data_sources[0][indices])

# %%
#Extract the data matrices

mnist_train_X = (mnist_train.data_sources[0].reshape(mnist_train.num_examples, -1) / 255.0).astype(np.single)
mnist_train_Y = mnist_train.data_sources[1].ravel()

mnist_valid_X = (mnist_validation.data_sources[0].reshape(mnist_validation.num_examples, -1) / 255.0).astype(np.single)
mnist_valid_Y = mnist_validation.data_sources[1].ravel()

# %%
from scipy.stats import mode

def KNN(train_X, train_Y, test_X, test_Y, ks, batch_size=100):
    """
    Compute error rate for various
    """
    errs = np.zeros((len(ks),))
    for i in xrange(0,test_Y.shape[0], batch_size):
        batch_X = test_X[i: i + batch_size]
        batch_Y = test_Y[i: i + batch_size]
        print("Examples %d:%d Computing distances... " % (i, i + batch_size), end='')
        #
        # TODO: fill in an efficient distance matrix computation 
        #
        # dists = np.array([np.sqrt(((train_X - test) ** 2).sum(axis=1)) for test in batch_X])
        dists = (((train_X[:, np.newaxis, :] - batch_X) ** 2).sum(axis=2))
        
        print("Sorting... ", end='')
        closest = np.argsort(dists, 0)
        
        print("Computing errors...")
        targets = train_Y[closest]
        
        for ki,k in enumerate(ks):
            predictions, unused_counts = mode(targets[:k,:], axis=0)
            predictions = predictions.ravel()
            #
            # TODO: fill in error count computation
            #
            errs[ki] += (batch_Y != predictions).sum()
        
    errs /= test_Y.shape    
    return np.vstack((ks, errs))

# %%
# train_X = mnist_train_X[:10]
# train_Y = mnist_train_Y[:10]
# test = mnist_valid_X[0: 10]
# dists = (((train_X[:, np.newaxis, :] - test) ** 2).sum(axis=2))
# closest = np.argsort(dists, 0)
# targets = train_Y[closest]
# print(targets)
# predictions, unused_counts = mode(targets[:10,:], axis=0)
# print(predictions.ravel(), unused_counts)
# print(train_Y)
# print((train_Y != predictions.ravel()).sum())

# %%
# Now find the best k on the validation set

mnist_validation_errs = KNN(mnist_train_X, mnist_train_Y, mnist_valid_X, mnist_valid_Y, [1,3,5,7,9])
plt.plot(mnist_validation_errs[0,:], mnist_validation_errs[1,:])

# %%
# Now use the best k to compute the test error

best_K =  mnist_validation_errs[0][np.argmin(mnist_validation_errs[1])]

mnist_full_train = MNIST(("train",), )

mnist_full_train_X = (mnist_full_train.data_sources[0].reshape(mnist_full_train.num_examples, -1) / 255.0).astype(np.single)
mnist_full_train_Y = mnist_full_train.data_sources[1].ravel()

mnist_test_X = (mnist_test.data_sources[0].reshape(mnist_test.num_examples, -1) / 255.0).astype(np.single)
mnist_test_Y = mnist_test.data_sources[1].ravel()

mnist_test_errs = KNN(mnist_full_train_X, mnist_full_train_Y, mnist_test_X, mnist_test_Y, [best_K])
print("When k=%d the test error rate is %.1f%%" % (mnist_test_errs[0,0], mnist_test_errs[1,0]*100.0))
# Out:
# Examples 0:200 Computing distances...  Sorting...  Computing errors...
# Examples 200:400 Computing distances...
# /pio/lscratch/1/os/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:24: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#  Sorting...  Computing errors...
# Examples 400:600 Computing distances...  Sorting...  Computing errors...
# Examples 600:800 Computing distances...  Sorting...  Computing errors...
# Examples 800:1000 Computing distances...  Sorting...  Computing errors...
# Examples 1000:1200 Computing distances...  Sorting...  Computing errors...
# Examples 1200:1400 Computing distances...  Sorting...  Computing errors...
# Examples 1400:1600 Computing distances...  Sorting...  Computing errors...
# Examples 1600:1800 Computing distances...  Sorting...  Computing errors...
# Examples 1800:2000 Computing distances...  Sorting...  Computing errors...
# Examples 2000:2200 Computing distances...  Sorting...  Computing errors...
# Examples 2200:2400 Computing distances...  Sorting...  Computing errors...
# Examples 2400:2600 Computing distances...  Sorting...  Computing errors...
# Examples 2600:2800 Computing distances...  Sorting...  Computing errors...
# Examples 2800:3000 Computing distances...  Sorting...  Computing errors...
# Examples 3000:3200 Computing distances...  Sorting...  Computing errors...
# Examples 3200:3400 Computing distances...  Sorting...  Computing errors...
# Examples 3400:3600 Computing distances...  Sorting...  Computing errors...
# Examples 3600:3800 Computing distances...  Sorting...  Computing errors...
# Examples 3800:4000 Computing distances...  Sorting...  Computing errors...
# Examples 4000:4200 Computing distances...  Sorting...  Computing errors...
# Examples 4200:4400 Computing distances...  Sorting...  Computing errors...
# Examples 4400:4600 Computing distances...  Sorting...  Computing errors...
# Examples 4600:4800 Computing distances...  Sorting...  Computing errors...
# Examples 4800:5000 Computing distances...  Sorting...  Computing errors...
# Examples 5000:5200 Computing distances...  Sorting...  Computing errors...
# Examples 5200:5400 Computing distances...  Sorting...  Computing errors...
# Examples 5400:5600 Computing distances...  Sorting...  Computing errors...
# Examples 5600:5800 Computing distances...  Sorting...  Computing errors...
# Examples 5800:6000 Computing distances...  Sorting...  Computing errors...
# Examples 6000:6200 Computing distances...  Sorting...  Computing errors...
# Examples 6200:6400 Computing distances...  Sorting...  Computing errors...
# Examples 6400:6600 Computing distances...  Sorting...  Computing errors...
# Examples 6600:6800 Computing distances...  Sorting...  Computing errors...
# Examples 6800:7000 Computing distances...  Sorting...  Computing errors...
# Examples 7000:7200 Computing distances...  Sorting...  Computing errors...
# Examples 7200:7400 Computing distances...  Sorting...  Computing errors...
# Examples 7400:7600 Computing distances...  Sorting...  Computing errors...
# Examples 7600:7800 Computing distances...  Sorting...  Computing errors...
# Examples 7800:8000 Computing distances...  Sorting...  Computing errors...
# Examples 8000:8200 Computing distances...  Sorting...  Computing errors...
# Examples 8200:8400 Computing distances...  Sorting...  Computing errors...
# Examples 8400:8600 Computing distances...  Sorting...  Computing errors...
# Examples 8600:8800 Computing distances...  Sorting...  Computing errors...
# Examples 8800:9000 Computing distances...  Sorting...  Computing errors...
# Examples 9000:9200 Computing distances...  Sorting...  Computing errors...
# Examples 9200:9400 Computing distances...  Sorting...  Computing errors...
# Examples 9400:9600 Computing distances...  Sorting...  Computing errors...
# Examples 9600:9800 Computing distances...  Sorting...  Computing errors...
# Examples 9800:10000 Computing distances...  Sorting...  Computing errors...
# When k=3 the test error rate is 2.9%

# %%
#
# Now repeat the k-NN training for CIFAR10
#
cifar10_train_X = (cifar10_train.data_sources[0].reshape(cifar10_train.num_examples, -1) / 255.0).astype(np.single)
cifar10_train_Y = cifar10_train.data_sources[1].ravel()

cifar10_valid_X = (cifar10_validation.data_sources[0].reshape(cifar10_validation.num_examples, -1) / 255.0).astype(np.single)
cifar10_valid_Y = cifar10_validation.data_sources[1].ravel()


# Now find the best k on the validation set

cifar10_validation_errs = KNN(cifar10_train_X, cifar10_train_Y, cifar10_valid_X, cifar10_valid_Y, [1,3,5,7,9], batch_size=40)
plt.plot(cifar10_validation_errs[0,:], cifar10_validation_errs[1,:])
# Out:
# Examples 0:40 Computing distances... Sorting... Computing errors...
# Examples 40:80 Computing distances... Sorting... Computing errors...
# Examples 80:120 Computing distances... Sorting... Computing errors...
# Examples 120:160 Computing distances... Sorting... Computing errors...
# Examples 160:200 Computing distances... Sorting... Computing errors...
# Examples 200:240 Computing distances... Sorting... Computing errors...
# Examples 240:280 Computing distances... Sorting... Computing errors...
# Examples 280:320 Computing distances... Sorting... Computing errors...
# Examples 320:360 Computing distances... Sorting... Computing errors...
# Examples 360:400 Computing distances... Sorting... Computing errors...
# Examples 400:440 Computing distances... Sorting... Computing errors...
# Examples 440:480 Computing distances... Sorting... Computing errors...
# Examples 480:520 Computing distances... Sorting... Computing errors...
# Examples 520:560 Computing distances... Sorting... Computing errors...
# Examples 560:600 Computing distances... Sorting... Computing errors...
# Examples 600:640 Computing distances... Sorting... Computing errors...
# Examples 640:680 Computing distances... Sorting... Computing errors...
# Examples 680:720 Computing distances... Sorting... Computing errors...
# Examples 720:760 Computing distances... Sorting... Computing errors...
# Examples 760:800 Computing distances... Sorting... Computing errors...
# Examples 800:840 Computing distances... Sorting... Computing errors...
# Examples 840:880 Computing distances... Sorting... Computing errors...
# Examples 880:920 Computing distances... Sorting... Computing errors...
# Examples 920:960 Computing distances... Sorting... Computing errors...
# Examples 960:1000 Computing distances... Sorting... Computing errors...
# Examples 1000:1040 Computing distances... Sorting... Computing errors...
# Examples 1040:1080 Computing distances... Sorting... Computing errors...
# Examples 1080:1120 Computing distances... Sorting... Computing errors...
# Examples 1120:1160 Computing distances... Sorting... Computing errors...
# Examples 1160:1200 Computing distances... Sorting... Computing errors...
# Examples 1200:1240 Computing distances... Sorting... Computing errors...
# Examples 1240:1280 Computing distances... Sorting... Computing errors...
# Examples 1280:1320 Computing distances... Sorting... Computing errors...
# Examples 1320:1360 Computing distances... Sorting... Computing errors...
# Examples 1360:1400 Computing distances... Sorting... Computing errors...
# Examples 1400:1440 Computing distances... Sorting... Computing errors...
# Examples 1440:1480 Computing distances... Sorting... Computing errors...
# Examples 1480:1520 Computing distances... Sorting... Computing errors...
# Examples 1520:1560 Computing distances... Sorting... Computing errors...
# Examples 1560:1600 Computing distances... Sorting... Computing errors...
# Examples 1600:1640 Computing distances... Sorting... Computing errors...
# Examples 1640:1680 Computing distances... Sorting... Computing errors...
# Examples 1680:1720 Computing distances... Sorting... Computing errors...
# Examples 1720:1760 Computing distances... Sorting... Computing errors...
# Examples 1760:1800 Computing distances... Sorting... Computing errors...
# Examples 1800:1840 Computing distances... Sorting... Computing errors...
# Examples 1840:1880 Computing distances... Sorting... Computing errors...
# Examples 1880:1920 Computing distances... Sorting... Computing errors...
# Examples 1920:1960 Computing distances... Sorting... Computing errors...
# Examples 1960:2000 Computing distances... Sorting... Computing errors...
# Examples 2000:2040 Computing distances... Sorting... Computing errors...
# Examples 2040:2080 Computing distances... Sorting... Computing errors...
# Examples 2080:2120 Computing distances... Sorting... Computing errors...
# Examples 2120:2160 Computing distances... Sorting... Computing errors...
# Examples 2160:2200 Computing distances... Sorting... Computing errors...
# Examples 2200:2240 Computing distances... Sorting... Computing errors...
# Examples 2240:2280 Computing distances... Sorting... Computing errors...
# Examples 2280:2320 Computing distances... Sorting... Computing errors...
# Examples 2320:2360 Computing distances... Sorting... Computing errors...
# Examples 2360:2400 Computing distances... Sorting... Computing errors...
# Examples 2400:2440 Computing distances... Sorting... Computing errors...
# Examples 2440:2480 Computing distances... Sorting... Computing errors...
# Examples 2480:2520 Computing distances... Sorting... Computing errors...
# Examples 2520:2560 Computing distances... Sorting... Computing errors...
# Examples 2560:2600 Computing distances... Sorting... Computing errors...
# Examples 2600:2640 Computing distances... Sorting... Computing errors...
# Examples 2640:2680 Computing distances... Sorting... Computing errors...
# Examples 2680:2720 Computing distances... Sorting... Computing errors...
# Examples 2720:2760 Computing distances... Sorting... Computing errors...
# Examples 2760:2800 Computing distances... Sorting... Computing errors...
# Examples 2800:2840 Computing distances... Sorting... Computing errors...
# Examples 2840:2880 Computing distances... Sorting... Computing errors...
# Examples 2880:2920 Computing distances... Sorting... Computing errors...
# Examples 2920:2960 Computing distances... Sorting... Computing errors...
# Examples 2960:3000 Computing distances... Sorting... Computing errors...
# Examples 3000:3040 Computing distances... Sorting... Computing errors...
# Examples 3040:3080 Computing distances... Sorting... Computing errors...
# Examples 3080:3120 Computing distances... Sorting... Computing errors...
# Examples 3120:3160 Computing distances... Sorting... Computing errors...
# Examples 3160:3200 Computing distances... Sorting... Computing errors...
# Examples 3200:3240 Computing distances... Sorting... Computing errors...
# Examples 3240:3280 Computing distances... Sorting... Computing errors...
# Examples 3280:3320 Computing distances... Sorting... Computing errors...
# Examples 3320:3360 Computing distances... Sorting... Computing errors...
# Examples 3360:3400 Computing distances... Sorting... Computing errors...
# Examples 3400:3440 Computing distances... Sorting... Computing errors...
# Examples 3440:3480 Computing distances... Sorting... Computing errors...
# Examples 3480:3520 Computing distances... Sorting... Computing errors...
# Examples 3520:3560 Computing distances... Sorting... Computing errors...
# Examples 3560:3600 Computing distances... Sorting... Computing errors...
# Examples 3600:3640 Computing distances... Sorting... Computing errors...
# Examples 3640:3680 Computing distances... Sorting... Computing errors...
# Examples 3680:3720 Computing distances... Sorting... Computing errors...
# Examples 3720:3760 Computing distances... Sorting... Computing errors...
# Examples 3760:3800 Computing distances... Sorting... Computing errors...
# Examples 3800:3840 Computing distances... Sorting... Computing errors...
# Examples 3840:3880 Computing distances... Sorting... Computing errors...
# Examples 3880:3920 Computing distances... Sorting... Computing errors...
# Examples 3920:3960 Computing distances... Sorting... Computing errors...
# Examples 3960:4000 Computing distances... Sorting... Computing errors...
# Examples 4000:4040 Computing distances... Sorting... Computing errors...
# Examples 4040:4080 Computing distances... Sorting... Computing errors...
# Examples 4080:4120 Computing distances... Sorting... Computing errors...
# Examples 4120:4160 Computing distances... Sorting... Computing errors...
# Examples 4160:4200 Computing distances... Sorting... Computing errors...
# Examples 4200:4240 Computing distances... Sorting... Computing errors...
# Examples 4240:4280 Computing distances... Sorting... Computing errors...
# Examples 4280:4320 Computing distances... Sorting... Computing errors...
# Examples 4320:4360 Computing distances... Sorting... Computing errors...
# Examples 4360:4400 Computing distances... Sorting... Computing errors...
# Examples 4400:4440 Computing distances... Sorting... Computing errors...
# Examples 4440:4480 Computing distances... Sorting... Computing errors...
# Examples 4480:4520 Computing distances... Sorting... Computing errors...
# Examples 4520:4560 Computing distances... Sorting... Computing errors...
# Examples 4560:4600 Computing distances... Sorting... Computing errors...
# Examples 4600:4640 Computing distances... Sorting... Computing errors...
# Examples 4640:4680 Computing distances... Sorting... Computing errors...
# Examples 4680:4720 Computing distances... Sorting... Computing errors...
# Examples 4720:4760 Computing distances... Sorting... Computing errors...
# Examples 4760:4800 Computing distances... Sorting... Computing errors...
# Examples 4800:4840 Computing distances... Sorting... Computing errors...
# Examples 4840:4880 Computing distances... Sorting... Computing errors...
# Examples 4880:4920 Computing distances... Sorting... Computing errors...
# Examples 4920:4960 Computing distances... Sorting... Computing errors...
# Examples 4960:5000 Computing distances... Sorting... Computing errors...
# Examples 5000:5040 Computing distances... Sorting... Computing errors...
# Examples 5040:5080 Computing distances... Sorting... Computing errors...
# Examples 5080:5120 Computing distances... Sorting... Computing errors...
# Examples 5120:5160 Computing distances... Sorting... Computing errors...
# Examples 5160:5200 Computing distances... Sorting... Computing errors...
# Examples 5200:5240 Computing distances... Sorting... Computing errors...
# Examples 5240:5280 Computing distances... Sorting... Computing errors...
# Examples 5280:5320 Computing distances... Sorting... Computing errors...
# Examples 5320:5360 Computing distances... Sorting... Computing errors...
# Examples 5360:5400 Computing distances... Sorting... Computing errors...
# Examples 5400:5440 Computing distances... Sorting... Computing errors...
# Examples 5440:5480 Computing distances... Sorting... Computing errors...
# Examples 5480:5520 Computing distances... Sorting... Computing errors...
# Examples 5520:5560 Computing distances... Sorting... Computing errors...
# Examples 5560:5600 Computing distances... Sorting... Computing errors...
# Examples 5600:5640 Computing distances... Sorting... Computing errors...
# Examples 5640:5680 Computing distances... Sorting... Computing errors...
# Examples 5680:5720 Computing distances... Sorting... Computing errors...
# Examples 5720:5760 Computing distances... Sorting... Computing errors...
# Examples 5760:5800 Computing distances... Sorting... Computing errors...
# Examples 5800:5840 Computing distances... Sorting... Computing errors...
# Examples 5840:5880 Computing distances... Sorting... Computing errors...
# Examples 5880:5920 Computing distances... Sorting... Computing errors...
# Examples 5920:5960 Computing distances... Sorting... Computing errors...
# Examples 5960:6000 Computing distances... Sorting... Computing errors...
# Examples 6000:6040 Computing distances... Sorting... Computing errors...
# Examples 6040:6080 Computing distances... Sorting... Computing errors...
# Examples 6080:6120 Computing distances... Sorting... Computing errors...
# Examples 6120:6160 Computing distances... Sorting... Computing errors...
# Examples 6160:6200 Computing distances... Sorting... Computing errors...
# Examples 6200:6240 Computing distances... Sorting... Computing errors...
# Examples 6240:6280 Computing distances... Sorting... Computing errors...
# Examples 6280:6320 Computing distances... Sorting... Computing errors...
# Examples 6320:6360 Computing distances... Sorting... Computing errors...
# Examples 6360:6400 Computing distances... Sorting... Computing errors...
# Examples 6400:6440 Computing distances... Sorting... Computing errors...
# Examples 6440:6480 Computing distances... Sorting... Computing errors...
# Examples 6480:6520 Computing distances... Sorting... Computing errors...
# Examples 6520:6560 Computing distances... Sorting... Computing errors...
# Examples 6560:6600 Computing distances... Sorting... Computing errors...
# Examples 6600:6640 Computing distances... Sorting... Computing errors...
# Examples 6640:6680 Computing distances... Sorting... Computing errors...
# Examples 6680:6720 Computing distances... Sorting... Computing errors...
# Examples 6720:6760 Computing distances... Sorting... Computing errors...
# Examples 6760:6800 Computing distances... Sorting... Computing errors...
# Examples 6800:6840 Computing distances... Sorting... Computing errors...
# Examples 6840:6880 Computing distances... Sorting... Computing errors...
# Examples 6880:6920 Computing distances... Sorting... Computing errors...
# Examples 6920:6960 Computing distances... Sorting... Computing errors...
# Examples 6960:7000 Computing distances... Sorting... Computing errors...
# Examples 7000:7040 Computing distances... Sorting... Computing errors...
# Examples 7040:7080 Computing distances... Sorting... Computing errors...
# Examples 7080:7120 Computing distances... Sorting... Computing errors...
# Examples 7120:7160 Computing distances... Sorting... Computing errors...
# Examples 7160:7200 Computing distances... Sorting... Computing errors...
# Examples 7200:7240 Computing distances... Sorting... Computing errors...
# Examples 7240:7280 Computing distances... Sorting... Computing errors...
# Examples 7280:7320 Computing distances... Sorting... Computing errors...
# Examples 7320:7360 Computing distances... Sorting... Computing errors...
# Examples 7360:7400 Computing distances... Sorting... Computing errors...
# Examples 7400:7440 Computing distances... Sorting... Computing errors...
# Examples 7440:7480 Computing distances... Sorting... Computing errors...
# Examples 7480:7520 Computing distances... Sorting... Computing errors...
# Examples 7520:7560 Computing distances... Sorting... Computing errors...
# Examples 7560:7600 Computing distances... Sorting... Computing errors...
# Examples 7600:7640 Computing distances... Sorting... Computing errors...
# Examples 7640:7680 Computing distances... Sorting... Computing errors...
# Examples 7680:7720 Computing distances... Sorting... Computing errors...
# Examples 7720:7760 Computing distances... Sorting... Computing errors...
# Examples 7760:7800 Computing distances... Sorting... Computing errors...
# Examples 7800:7840 Computing distances... Sorting... Computing errors...
# Examples 7840:7880 Computing distances... Sorting... Computing errors...
# Examples 7880:7920 Computing distances... Sorting... Computing errors...
# Examples 7920:7960 Computing distances... Sorting... Computing errors...
# Examples 7960:8000 Computing distances... Sorting... Computing errors...
# Examples 8000:8040 Computing distances... Sorting... Computing errors...
# Examples 8040:8080 Computing distances... Sorting... Computing errors...
# Examples 8080:8120 Computing distances... Sorting... Computing errors...
# Examples 8120:8160 Computing distances... Sorting... Computing errors...
# Examples 8160:8200 Computing distances... Sorting... Computing errors...
# Examples 8200:8240 Computing distances... Sorting... Computing errors...
# Examples 8240:8280 Computing distances... Sorting... Computing errors...
# Examples 8280:8320 Computing distances... Sorting... Computing errors...
# Examples 8320:8360 Computing distances... Sorting... Computing errors...
# Examples 8360:8400 Computing distances... Sorting... Computing errors...
# Examples 8400:8440 Computing distances... Sorting... Computing errors...
# Examples 8440:8480 Computing distances... Sorting... Computing errors...
# Examples 8480:8520 Computing distances... Sorting... Computing errors...
# Examples 8520:8560 Computing distances... Sorting... Computing errors...
# Examples 8560:8600 Computing distances... Sorting... Computing errors...
# Examples 8600:8640 Computing distances... Sorting... Computing errors...
# Examples 8640:8680 Computing distances... Sorting... Computing errors...
# Examples 8680:8720 Computing distances... Sorting... Computing errors...
# Examples 8720:8760 Computing distances... Sorting... Computing errors...
# Examples 8760:8800 Computing distances... Sorting... Computing errors...
# Examples 8800:8840 Computing distances... Sorting... Computing errors...
# Examples 8840:8880 Computing distances... Sorting... Computing errors...
# Examples 8880:8920 Computing distances... Sorting... Computing errors...
# Examples 8920:8960 Computing distances... Sorting... Computing errors...
# Examples 8960:9000 Computing distances... Sorting... Computing errors...
# Examples 9000:9040 Computing distances... Sorting... Computing errors...
# Examples 9040:9080 Computing distances... Sorting... Computing errors...
# Examples 9080:9120 Computing distances... Sorting... Computing errors...
# Examples 9120:9160 Computing distances... Sorting... Computing errors...
# Examples 9160:9200 Computing distances... Sorting... Computing errors...
# Examples 9200:9240 Computing distances... Sorting... Computing errors...
# Examples 9240:9280 Computing distances... Sorting... Computing errors...
# Examples 9280:9320 Computing distances... Sorting... Computing errors...
# Examples 9320:9360 Computing distances... Sorting... Computing errors...
# Examples 9360:9400 Computing distances... Sorting... Computing errors...
# Examples 9400:9440 Computing distances... Sorting... Computing errors...
# Examples 9440:9480 Computing distances... Sorting... Computing errors...
# Examples 9480:9520 Computing distances... Sorting... Computing errors...
# Examples 9520:9560 Computing distances... Sorting... Computing errors...
# Examples 9560:9600 Computing distances... Sorting... Computing errors...
# Examples 9600:9640 Computing distances... Sorting... Computing errors...
# Examples 9640:9680 Computing distances... Sorting... Computing errors...
# Examples 9680:9720 Computing distances... Sorting... Computing errors...
# Examples 9720:9760 Computing distances... Sorting... Computing errors...
# Examples 9760:9800 Computing distances... Sorting... Computing errors...
# Examples 9800:9840 Computing distances... Sorting... Computing errors...
# Examples 9840:9880 Computing distances... Sorting... Computing errors...
# Examples 9880:9920 Computing distances... Sorting... Computing errors...
# Examples 9920:9960 Computing distances... Sorting... Computing errors...
# Examples 9960:10000 Computing distances... Sorting... Computing errors...

# %%
# Now use the best k to compute the test error

best_K =  cifar10_validation_errs[0][np.argmin(cifar10_validation_errs[1])]

cifar10_full_train = CIFAR10(("train",), )

cifar10_full_train_X = (cifar10_full_train.data_sources[0].reshape(cifar10_full_train.num_examples, -1) / 255.0).astype(np.single)
cifar10_full_train_Y = cifar10_full_train.data_sources[1].ravel()

cifar10_test_X = (cifar10_test.data_sources[0].reshape(cifar10_test.num_examples, -1) / 255.0).astype(np.single)
cifar10_test_Y = cifar10_test.data_sources[1].ravel()

cifar10_test_errs = KNN(cifar10_full_train_X, cifar10_full_train_Y, cifar10_test_X, cifar10_test_Y, [best_K], batch_size=30)
print("When k=%d the test error rate is %.1f%%" % (cifar10_test_errs[0,0], cifar10_test_errs[1,0]*100.0))
# Out:
# Examples 0:30 Computing distances... Sorting... Computing errors...
# /pio/lscratch/1/os/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:25: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# Examples 30:60 Computing distances... Sorting... Computing errors...
# Examples 60:90 Computing distances... Sorting... Computing errors...
# Examples 90:120 Computing distances... Sorting... Computing errors...
# Examples 120:150 Computing distances... Sorting... Computing errors...
# Examples 150:180 Computing distances... Sorting... Computing errors...
# Examples 180:210 Computing distances... Sorting... Computing errors...
# Examples 210:240 Computing distances... Sorting... Computing errors...
# Examples 240:270 Computing distances... Sorting... Computing errors...
# Examples 270:300 Computing distances... Sorting... Computing errors...
# Examples 300:330 Computing distances... Sorting... Computing errors...
# Examples 330:360 Computing distances... Sorting... Computing errors...
# Examples 360:390 Computing distances... Sorting... Computing errors...
# Examples 390:420 Computing distances... Sorting... Computing errors...
# Examples 420:450 Computing distances... Sorting... Computing errors...
# Examples 450:480 Computing distances... Sorting... Computing errors...
# Examples 480:510 Computing distances... Sorting... Computing errors...
# Examples 510:540 Computing distances... Sorting... Computing errors...
# Examples 540:570 Computing distances... Sorting... Computing errors...
# Examples 570:600 Computing distances... Sorting... Computing errors...
# Examples 600:630 Computing distances... Sorting... Computing errors...
# Examples 630:660 Computing distances... Sorting... Computing errors...
# Examples 660:690 Computing distances... Sorting... Computing errors...
# Examples 690:720 Computing distances... Sorting... Computing errors...
# Examples 720:750 Computing distances... Sorting... Computing errors...
# Examples 750:780 Computing distances... Sorting... Computing errors...
# Examples 780:810 Computing distances... Sorting... Computing errors...
# Examples 810:840 Computing distances... Sorting... Computing errors...
# Examples 840:870 Computing distances... Sorting... Computing errors...
# Examples 870:900 Computing distances... Sorting... Computing errors...
# Examples 900:930 Computing distances... Sorting... Computing errors...
# Examples 930:960 Computing distances... Sorting... Computing errors...
# Examples 960:990 Computing distances... Sorting... Computing errors...
# Examples 990:1020 Computing distances... Sorting... Computing errors...
# Examples 1020:1050 Computing distances... Sorting... Computing errors...
# Examples 1050:1080 Computing distances... Sorting... Computing errors...
# Examples 1080:1110 Computing distances... Sorting... Computing errors...
# Examples 1110:1140 Computing distances... Sorting... Computing errors...
# Examples 1140:1170 Computing distances... Sorting... Computing errors...
# Examples 1170:1200 Computing distances... Sorting... Computing errors...
# Examples 1200:1230 Computing distances... Sorting... Computing errors...
# Examples 1230:1260 Computing distances... Sorting... Computing errors...
# Examples 1260:1290 Computing distances... Sorting... Computing errors...
# Examples 1290:1320 Computing distances... Sorting... Computing errors...
# Examples 1320:1350 Computing distances... Sorting... Computing errors...
# Examples 1350:1380 Computing distances... Sorting... Computing errors...
# Examples 1380:1410 Computing distances... Sorting... Computing errors...
# Examples 1410:1440 Computing distances... Sorting... Computing errors...
# Examples 1440:1470 Computing distances... Sorting... Computing errors...
# Examples 1470:1500 Computing distances... Sorting... Computing errors...
# Examples 1500:1530 Computing distances... Sorting... Computing errors...
# Examples 1530:1560 Computing distances... Sorting... Computing errors...
# Examples 1560:1590 Computing distances... Sorting... Computing errors...
# Examples 1590:1620 Computing distances... Sorting... Computing errors...
# Examples 1620:1650 Computing distances... Sorting... Computing errors...
# Examples 1650:1680 Computing distances... Sorting... Computing errors...
# Examples 1680:1710 Computing distances... Sorting... Computing errors...
# Examples 1710:1740 Computing distances... Sorting... Computing errors...
# Examples 1740:1770 Computing distances... Sorting... Computing errors...
# Examples 1770:1800 Computing distances... Sorting... Computing errors...
# Examples 1800:1830 Computing distances... Sorting... Computing errors...
# Examples 1830:1860 Computing distances... Sorting... Computing errors...
# Examples 1860:1890 Computing distances... Sorting... Computing errors...
# Examples 1890:1920 Computing distances... Sorting... Computing errors...
# Examples 1920:1950 Computing distances... Sorting... Computing errors...
# Examples 1950:1980 Computing distances... Sorting... Computing errors...
# Examples 1980:2010 Computing distances... Sorting... Computing errors...
# Examples 2010:2040 Computing distances... Sorting... Computing errors...
# Examples 2040:2070 Computing distances... Sorting... Computing errors...
# Examples 2070:2100 Computing distances... Sorting... Computing errors...
# Examples 2100:2130 Computing distances... Sorting... Computing errors...
# Examples 2130:2160 Computing distances... Sorting... Computing errors...
# Examples 2160:2190 Computing distances... Sorting... Computing errors...
# Examples 2190:2220 Computing distances... Sorting... Computing errors...
# Examples 2220:2250 Computing distances... Sorting... Computing errors...
# Examples 2250:2280 Computing distances... Sorting... Computing errors...
# Examples 2280:2310 Computing distances... Sorting... Computing errors...
# Examples 2310:2340 Computing distances... Sorting... Computing errors...
# Examples 2340:2370 Computing distances... Sorting... Computing errors...
# Examples 2370:2400 Computing distances... Sorting... Computing errors...
# Examples 2400:2430 Computing distances... Sorting... Computing errors...
# Examples 2430:2460 Computing distances... Sorting... Computing errors...
# Examples 2460:2490 Computing distances... Sorting... Computing errors...
# Examples 2490:2520 Computing distances... Sorting... Computing errors...
# Examples 2520:2550 Computing distances... Sorting... Computing errors...
# Examples 2550:2580 Computing distances... Sorting... Computing errors...
# Examples 2580:2610 Computing distances... Sorting... Computing errors...
# Examples 2610:2640 Computing distances... Sorting... Computing errors...
# Examples 2640:2670 Computing distances... Sorting... Computing errors...
# Examples 2670:2700 Computing distances... Sorting... Computing errors...
# Examples 2700:2730 Computing distances... Sorting... Computing errors...
# Examples 2730:2760 Computing distances... Sorting... Computing errors...
# Examples 2760:2790 Computing distances... Sorting... Computing errors...
# Examples 2790:2820 Computing distances... Sorting... Computing errors...
# Examples 2820:2850 Computing distances... Sorting... Computing errors...
# Examples 2850:2880 Computing distances... Sorting... Computing errors...
# Examples 2880:2910 Computing distances... Sorting... Computing errors...
# Examples 2910:2940 Computing distances... Sorting... Computing errors...
# Examples 2940:2970 Computing distances... Sorting... Computing errors...
# Examples 2970:3000 Computing distances... Sorting... Computing errors...
# Examples 3000:3030 Computing distances... Sorting... Computing errors...
# Examples 3030:3060 Computing distances... Sorting... Computing errors...
# Examples 3060:3090 Computing distances... Sorting... Computing errors...
# Examples 3090:3120 Computing distances... Sorting... Computing errors...
# Examples 3120:3150 Computing distances... Sorting... Computing errors...
# Examples 3150:3180 Computing distances... Sorting... Computing errors...
# Examples 3180:3210 Computing distances... Sorting... Computing errors...
# Examples 3210:3240 Computing distances... Sorting... Computing errors...
# Examples 3240:3270 Computing distances... Sorting... Computing errors...
# Examples 3270:3300 Computing distances... Sorting... Computing errors...
# Examples 3300:3330 Computing distances... Sorting... Computing errors...
# Examples 3330:3360 Computing distances... Sorting... Computing errors...
# Examples 3360:3390 Computing distances... Sorting... Computing errors...
# Examples 3390:3420 Computing distances... Sorting... Computing errors...
# Examples 3420:3450 Computing distances... Sorting... Computing errors...
# Examples 3450:3480 Computing distances... Sorting... Computing errors...
# Examples 3480:3510 Computing distances... Sorting... Computing errors...
# Examples 3510:3540 Computing distances... Sorting... Computing errors...
# Examples 3540:3570 Computing distances... Sorting... Computing errors...
# Examples 3570:3600 Computing distances... Sorting... Computing errors...
# Examples 3600:3630 Computing distances... Sorting... Computing errors...
# Examples 3630:3660 Computing distances... Sorting... Computing errors...
# Examples 3660:3690 Computing distances... Sorting... Computing errors...
# Examples 3690:3720 Computing distances... Sorting... Computing errors...
# Examples 3720:3750 Computing distances... Sorting... Computing errors...
# Examples 3750:3780 Computing distances... Sorting... Computing errors...
# Examples 3780:3810 Computing distances... Sorting... Computing errors...
# Examples 3810:3840 Computing distances... Sorting... Computing errors...
# Examples 3840:3870 Computing distances... Sorting... Computing errors...
# Examples 3870:3900 Computing distances... Sorting... Computing errors...
# Examples 3900:3930 Computing distances... Sorting... Computing errors...
# Examples 3930:3960 Computing distances... Sorting... Computing errors...
# Examples 3960:3990 Computing distances... Sorting... Computing errors...
# Examples 3990:4020 Computing distances... Sorting... Computing errors...
# Examples 4020:4050 Computing distances... Sorting... Computing errors...
# Examples 4050:4080 Computing distances... Sorting... Computing errors...
# Examples 4080:4110 Computing distances... Sorting... Computing errors...
# Examples 4110:4140 Computing distances... Sorting... Computing errors...
# Examples 4140:4170 Computing distances... Sorting... Computing errors...
# Examples 4170:4200 Computing distances... Sorting... Computing errors...
# Examples 4200:4230 Computing distances... Sorting... Computing errors...
# Examples 4230:4260 Computing distances... Sorting... Computing errors...
# Examples 4260:4290 Computing distances... Sorting... Computing errors...
# Examples 4290:4320 Computing distances... Sorting... Computing errors...
# Examples 4320:4350 Computing distances... Sorting... Computing errors...
# Examples 4350:4380 Computing distances... Sorting... Computing errors...
# Examples 4380:4410 Computing distances... Sorting... Computing errors...
# Examples 4410:4440 Computing distances... Sorting... Computing errors...
# Examples 4440:4470 Computing distances... Sorting... Computing errors...
# Examples 4470:4500 Computing distances... Sorting... Computing errors...
# Examples 4500:4530 Computing distances... Sorting... Computing errors...
# Examples 4530:4560 Computing distances... Sorting... Computing errors...
# Examples 4560:4590 Computing distances... Sorting... Computing errors...
# Examples 4590:4620 Computing distances... Sorting... Computing errors...
# Examples 4620:4650 Computing distances... Sorting... Computing errors...
# Examples 4650:4680 Computing distances... Sorting... Computing errors...
# Examples 4680:4710 Computing distances... Sorting... Computing errors...
# Examples 4710:4740 Computing distances... Sorting... Computing errors...
# Examples 4740:4770 Computing distances... Sorting... Computing errors...
# Examples 4770:4800 Computing distances... Sorting... Computing errors...
# Examples 4800:4830 Computing distances... Sorting... Computing errors...
# Examples 4830:4860 Computing distances... Sorting... Computing errors...
# Examples 4860:4890 Computing distances... Sorting... Computing errors...
# Examples 4890:4920 Computing distances... Sorting... Computing errors...
# Examples 4920:4950 Computing distances... Sorting... Computing errors...
# Examples 4950:4980 Computing distances... Sorting... Computing errors...
# Examples 4980:5010 Computing distances... Sorting... Computing errors...
# Examples 5010:5040 Computing distances... Sorting... Computing errors...
# Examples 5040:5070 Computing distances... Sorting... Computing errors...
# Examples 5070:5100 Computing distances... Sorting... Computing errors...
# Examples 5100:5130 Computing distances... Sorting... Computing errors...
# Examples 5130:5160 Computing distances... Sorting... Computing errors...
# Examples 5160:5190 Computing distances... Sorting... Computing errors...
# Examples 5190:5220 Computing distances... Sorting... Computing errors...
# Examples 5220:5250 Computing distances... Sorting... Computing errors...
# Examples 5250:5280 Computing distances... Sorting... Computing errors...
# Examples 5280:5310 Computing distances... Sorting... Computing errors...
# Examples 5310:5340 Computing distances... Sorting... Computing errors...
# Examples 5340:5370 Computing distances... Sorting... Computing errors...
# Examples 5370:5400 Computing distances... Sorting... Computing errors...
# Examples 5400:5430 Computing distances... Sorting... Computing errors...
# Examples 5430:5460 Computing distances... Sorting... Computing errors...
# Examples 5460:5490 Computing distances... Sorting... Computing errors...
# Examples 5490:5520 Computing distances... Sorting... Computing errors...
# Examples 5520:5550 Computing distances... Sorting... Computing errors...
# Examples 5550:5580 Computing distances... Sorting... Computing errors...
# Examples 5580:5610 Computing distances... Sorting... Computing errors...
# Examples 5610:5640 Computing distances... Sorting... Computing errors...
# Examples 5640:5670 Computing distances... Sorting... Computing errors...
# Examples 5670:5700 Computing distances... Sorting... Computing errors...
# Examples 5700:5730 Computing distances... Sorting... Computing errors...
# Examples 5730:5760 Computing distances... Sorting... Computing errors...
# Examples 5760:5790 Computing distances... Sorting... Computing errors...
# Examples 5790:5820 Computing distances... Sorting... Computing errors...
# Examples 5820:5850 Computing distances... Sorting... Computing errors...
# Examples 5850:5880 Computing distances... Sorting... Computing errors...
# Examples 5880:5910 Computing distances... Sorting... Computing errors...
# Examples 5910:5940 Computing distances... Sorting... Computing errors...
# Examples 5940:5970 Computing distances... Sorting... Computing errors...
# Examples 5970:6000 Computing distances... Sorting... Computing errors...
# Examples 6000:6030 Computing distances... Sorting... Computing errors...
# Examples 6030:6060 Computing distances... Sorting... Computing errors...
# Examples 6060:6090 Computing distances... Sorting... Computing errors...
# Examples 6090:6120 Computing distances... Sorting... Computing errors...
# Examples 6120:6150 Computing distances... Sorting... Computing errors...
# Examples 6150:6180 Computing distances... Sorting... Computing errors...
# Examples 6180:6210 Computing distances... Sorting... Computing errors...
# Examples 6210:6240 Computing distances... Sorting... Computing errors...
# Examples 6240:6270 Computing distances... Sorting... Computing errors...
# Examples 6270:6300 Computing distances... Sorting... Computing errors...
# Examples 6300:6330 Computing distances... Sorting... Computing errors...
# Examples 6330:6360 Computing distances... Sorting... Computing errors...
# Examples 6360:6390 Computing distances... Sorting... Computing errors...
# Examples 6390:6420 Computing distances... Sorting... Computing errors...
# Examples 6420:6450 Computing distances... Sorting... Computing errors...
# Examples 6450:6480 Computing distances... Sorting... Computing errors...
# Examples 6480:6510 Computing distances... Sorting... Computing errors...
# Examples 6510:6540 Computing distances... Sorting... Computing errors...
# Examples 6540:6570 Computing distances... Sorting... Computing errors...
# Examples 6570:6600 Computing distances... Sorting... Computing errors...
# Examples 6600:6630 Computing distances... Sorting... Computing errors...
# Examples 6630:6660 Computing distances... Sorting... Computing errors...
# Examples 6660:6690 Computing distances... Sorting... Computing errors...
# Examples 6690:6720 Computing distances... Sorting... Computing errors...
# Examples 6720:6750 Computing distances... Sorting... Computing errors...
# Examples 6750:6780 Computing distances... Sorting... Computing errors...
# Examples 6780:6810 Computing distances... Sorting... Computing errors...
# Examples 6810:6840 Computing distances... Sorting... Computing errors...
# Examples 6840:6870 Computing distances... Sorting... Computing errors...
# Examples 6870:6900 Computing distances... Sorting... Computing errors...
# Examples 6900:6930 Computing distances... Sorting... Computing errors...
# Examples 6930:6960 Computing distances... Sorting... Computing errors...
# Examples 6960:6990 Computing distances... Sorting... Computing errors...
# Examples 6990:7020 Computing distances... Sorting... Computing errors...
# Examples 7020:7050 Computing distances... Sorting... Computing errors...
# Examples 7050:7080 Computing distances... Sorting... Computing errors...
# Examples 7080:7110 Computing distances... Sorting... Computing errors...
# Examples 7110:7140 Computing distances... Sorting... Computing errors...
# Examples 7140:7170 Computing distances... Sorting... Computing errors...
# Examples 7170:7200 Computing distances... Sorting... Computing errors...
# Examples 7200:7230 Computing distances... Sorting... Computing errors...
# Examples 7230:7260 Computing distances... Sorting... Computing errors...
# Examples 7260:7290 Computing distances... Sorting... Computing errors...
# Examples 7290:7320 Computing distances... Sorting... Computing errors...
# Examples 7320:7350 Computing distances... Sorting... Computing errors...
# Examples 7350:7380 Computing distances... Sorting... Computing errors...
# Examples 7380:7410 Computing distances... Sorting... Computing errors...
# Examples 7410:7440 Computing distances... Sorting... Computing errors...
# Examples 7440:7470 Computing distances... Sorting... Computing errors...
# Examples 7470:7500 Computing distances... Sorting... Computing errors...
# Examples 7500:7530 Computing distances... Sorting... Computing errors...
# Examples 7530:7560 Computing distances... Sorting... Computing errors...
# Examples 7560:7590 Computing distances... Sorting... Computing errors...
# Examples 7590:7620 Computing distances... Sorting... Computing errors...
# Examples 7620:7650 Computing distances... Sorting... Computing errors...
# Examples 7650:7680 Computing distances... Sorting... Computing errors...
# Examples 7680:7710 Computing distances... Sorting... Computing errors...
# Examples 7710:7740 Computing distances... Sorting... Computing errors...
# Examples 7740:7770 Computing distances... Sorting... Computing errors...
# Examples 7770:7800 Computing distances... Sorting... Computing errors...
# Examples 7800:7830 Computing distances... Sorting... Computing errors...
# Examples 7830:7860 Computing distances... Sorting... Computing errors...
# Examples 7860:7890 Computing distances... Sorting... Computing errors...
# Examples 7890:7920 Computing distances... Sorting... Computing errors...
# Examples 7920:7950 Computing distances... Sorting... Computing errors...
# Examples 7950:7980 Computing distances... Sorting... Computing errors...
# Examples 7980:8010 Computing distances... Sorting... Computing errors...
# Examples 8010:8040 Computing distances... Sorting... Computing errors...
# Examples 8040:8070 Computing distances... Sorting... Computing errors...
# Examples 8070:8100 Computing distances... Sorting... Computing errors...
# Examples 8100:8130 Computing distances... Sorting... Computing errors...
# Examples 8130:8160 Computing distances... Sorting... Computing errors...
# Examples 8160:8190 Computing distances... Sorting... Computing errors...
# Examples 8190:8220 Computing distances... Sorting... Computing errors...
# Examples 8220:8250 Computing distances... Sorting... Computing errors...
# Examples 8250:8280 Computing distances... Sorting... Computing errors...
# Examples 8280:8310 Computing distances... Sorting... Computing errors...
# Examples 8310:8340 Computing distances... Sorting... Computing errors...
# Examples 8340:8370 Computing distances... Sorting... Computing errors...
# Examples 8370:8400 Computing distances... Sorting... Computing errors...
# Examples 8400:8430 Computing distances... Sorting... Computing errors...
# Examples 8430:8460 Computing distances... Sorting... Computing errors...
# Examples 8460:8490 Computing distances... Sorting... Computing errors...
# Examples 8490:8520 Computing distances... Sorting... Computing errors...
# Examples 8520:8550 Computing distances... Sorting... Computing errors...
# Examples 8550:8580 Computing distances... Sorting... Computing errors...
# Examples 8580:8610 Computing distances... Sorting... Computing errors...
# Examples 8610:8640 Computing distances... Sorting... Computing errors...
# Examples 8640:8670 Computing distances... Sorting... Computing errors...
# Examples 8670:8700 Computing distances... Sorting... Computing errors...
# Examples 8700:8730 Computing distances... Sorting... Computing errors...
# Examples 8730:8760 Computing distances... Sorting... Computing errors...
# Examples 8760:8790 Computing distances... Sorting... Computing errors...
# Examples 8790:8820 Computing distances... Sorting... Computing errors...
# Examples 8820:8850 Computing distances... Sorting... Computing errors...
# Examples 8850:8880 Computing distances... Sorting... Computing errors...
# Examples 8880:8910 Computing distances... Sorting... Computing errors...
# Examples 8910:8940 Computing distances... Sorting... Computing errors...
# Examples 8940:8970 Computing distances... Sorting... Computing errors...
# Examples 8970:9000 Computing distances... Sorting... Computing errors...
# Examples 9000:9030 Computing distances... Sorting... Computing errors...
# Examples 9030:9060 Computing distances... Sorting... Computing errors...
# Examples 9060:9090 Computing distances... Sorting... Computing errors...
# Examples 9090:9120 Computing distances... Sorting... Computing errors...
# Examples 9120:9150 Computing distances... Sorting... Computing errors...
# Examples 9150:9180 Computing distances... Sorting... Computing errors...
# Examples 9180:9210 Computing distances... Sorting... Computing errors...
# Examples 9210:9240 Computing distances... Sorting... Computing errors...
# Examples 9240:9270 Computing distances... Sorting... Computing errors...
# Examples 9270:9300 Computing distances... Sorting... Computing errors...
# Examples 9300:9330 Computing distances... Sorting... Computing errors...
# Examples 9330:9360 Computing distances... Sorting... Computing errors...
# Examples 9360:9390 Computing distances... Sorting... Computing errors...
# Examples 9390:9420 Computing distances... Sorting... Computing errors...
# Examples 9420:9450 Computing distances... Sorting... Computing errors...
# Examples 9450:9480 Computing distances... Sorting... Computing errors...
# Examples 9480:9510 Computing distances... Sorting... Computing errors...
# Examples 9510:9540 Computing distances... Sorting... Computing errors...
# Examples 9540:9570 Computing distances... Sorting... Computing errors...
# Examples 9570:9600 Computing distances... Sorting... Computing errors...
# Examples 9600:9630 Computing distances... Sorting... Computing errors...
# Examples 9630:9660 Computing distances... Sorting... Computing errors...
# Examples 9660:9690 Computing distances... Sorting... Computing errors...
# Examples 9690:9720 Computing distances... Sorting... Computing errors...
# Examples 9720:9750 Computing distances... Sorting... Computing errors...
# Examples 9750:9780 Computing distances... Sorting... Computing errors...
# Examples 9780:9810 Computing distances... Sorting... Computing errors...
# Examples 9810:9840 Computing distances... Sorting... Computing errors...
# Examples 9840:9870 Computing distances... Sorting... Computing errors...
# Examples 9870:9900 Computing distances... Sorting... Computing errors...
# Examples 9900:9930 Computing distances... Sorting... Computing errors...
# Examples 9930:9960 Computing distances... Sorting... Computing errors...
# Examples 9960:9990 Computing distances... Sorting... Computing errors...
# Examples 9990:10020 Computing distances... Sorting... Computing errors...
# When k=1 the test error rate is 64.6%

# %% [markdown]
# # Locality sensitive hashing
#
# Problem 5 was about speeding up the inference using loops implicitly present in matrix multiplication instead of explicit loops in Python. In this problem, we will explore a strategy to truly reduce the total number of computations required to find nearest neighbors without sacrificing too much accuracy.
#
# To speed up nearest neighbor search we will employ *Locality Sensitive Hashing (LSH)* functions. For a given distance metric, the locality sensitive hash should put items that are similar into the same bucket. Notice that this is essentially a design choice opposite to traditional cryptographic hash functions that should amplify the difference of similar inputs (typically we want that small perturbations of data result in large changes to the hash value).
#
# One of the simplest implementations of LSH approximates the cosine distance. Let $x\in \mathbb{R}^N$ and $y\in \mathbb{R}^N$ be two vectors. Their cosine distance is defined as:
#
# \begin{equation}
#     d_\text{cos}(x,y) = \frac{x \cdot y}{\|x\| \|y\|} = \cos\left(\theta(x,y)\right),
# \end{equation}
# where $\theta(x,y)$ is the unsigned angle between $x$ and $y$.
#
# We will construct a family $H$ of hash functions that are an LSH for angle distances (an approximation to cosine distance). Assume $p\in \mathbb{R}^N$ is a random vector (components are sampled from the normal distribution) of length 1. Then define the hash function $h(x) = \text{sgn}(x\cdot p)$, where $\text{sgn()}$ is the sign function. It can be proven that:
#
# \begin{equation}
#     p_{h\in H}[h(x)=h(y)] = 1 - \frac{\theta(x,y)}{\pi}.
# \end{equation}
#
# The equation means that the probability of a hash collision grows as the the angle between two vectors gets smaller. Therefore, vectors that are close according to the cosine distance will be put with high probability into the same bin (we use the fact that for small $\theta$ we can approximate $\cos(\theta) = 1 - \theta/\pi$.
#
# We will say that a family of randomly chosen hash functions $H$ is $(d_1, d_2, p_1, p_2)$-sensitive with respect to a distance metric $d$ if for any $x$ and $y$:
# 1. If $d(x,y) \leq d_1$ then $p_{h\in H}[h(x)=h(y)] \geq p_1$.
# 2. If $d(x,y) \geq d_2$ then $p_{h\in H}[h(x)=h(y)] \leq p_2$.
#
# For example, our family of randomly chosen hyperplanes is $(d_1, d_2, (1-d_1)/\pi, (1-d_2)/\pi)$-sensitive.
#
# Ideally, vectors should be placed into the same bin with a high probability if their distance is smaller than a threshold, and with a low probability if their distance is larger that the threshold. By combining hashing functions we can get closer to this ideal sensitivity.
#
# Given a family of hash functions $H$ with sensitivity $(d_1, d_3, p_1, p_2)$ we can construct a new family $H'$ by combining $r$ functions from $H$:
# 1. AND: let $h=[h_1, h_2, \ldots, h_r] \in H'$ and $h(x)=h(y)$ if and only if $\forall_i h_i(x)=h_i(y)$. Then $H'$ is $(d_1, d_2, (p_1)^r, (p_2)^r)$-sensitive.
# 2. OR: let $h=[h_1, h_2, \ldots, h_r] \in H'$ and $h(x)=h(y)$ if and only if $\exists_i h_i(x)=h_i(y)$. Then $H'$ is $(d_1, d_2, 1-(1-p_1)^r, 1-(1-p_2)^r)$-sensitive.
#
# AND makes all probabilities shrink, but properly choosing $r$ we can make the lower probability approach 0 while the higher does not. Conversely, OR makes all probabilities grow, we can make the upper probability approach 1 while the lower does not.
#
#
#
# ## Problem 6 [2-4p bonus]
#
# 1. **[1bp]** **Note:** you can show sketches of proofs for this assignment.
#     1. Show that angle between vectors is a metric (https://en.wikipedia.org/wiki/Metric_(mathematics)).
#
#     2. Show that $p_{h\in H}[h(x)=h(y)] = 1 - \frac{\theta(x,y)}{\pi}$ for $h$ computed using a randomly chosen hyperplane.
#
#     3. Show the properties of either AND or OR boosting of LSH.
#
# 3. **[1-3bp]** Reimplement k-Nearest Neighbors for MNIST classification using the cosine distance instead of the Euclidean distance. Choose a sensible value of $k$. Use Locality Sensitive Hashing to achieve an error rate no greater than $150\%$ of the original error rate with at least a $90\%$ speedup (i.e., by considering on average at most 5000 training samples per query image). For a few settings plot the speedup-vs-accuracy relation.
#
#   **Note:** points will be awarded based on ingenuity of your solution. Feel free to explore your own ideas!
